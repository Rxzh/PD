# %% [markdown]
# # Choix des variables explicatives
#
# **But du notebook :** réaliser des tests statistiques sur les variables issues de Bloomberg afin d'identifier celles pertinentes pour la régression.
#
# Deux conditions à vérifier :
#
# $-$ La variable explicative doit être utile pour expliquer la variable à expliquer, c'est-à-dire que *PD_1y* (la proba de défaut à 1 an) doit être corrélée à la variable.
#
# $-$ Pas de doublons entre les variables explicatives. Les variables explicatives choisies doivent être peu corrélées entre elles.

# %% [markdown]
# ----------------
# # Résultats du notebook
#
# Variables d'intérêt : Average Equity / Average Assets, Common Eqty / Tot Assets, Int Exp / Avg Int Bear Liab, Debt/EBITDA, EBITDA, Earnings Assets / Int Bear Liab, Debt / Common Equity, BCLASS Level 3 *(sont statistiquement significatives par rapport à PD_1y)*
#
# **Variables d'intérêt moins les doublons : Common Eqty / Tot Assets, Debt/EBITDA, EBITDA, Earnings Assets / Int Bear Liab, Debt / Common Equity, BCLASS Level 3, Interest Coverage Ratio,TCE Ratio,Risk-Based Cap Ratio** *(statistiquement significatives et peu corrélées entre elles)*
#
# Variables d'intéret moins les doublons moins ceux avec bcp de valeurs manquantes : Common Eqty / Tot Assets, Debt / Common Equity, BCLASS Level 3, TCE Ratio *(statistiquement significatives, peu corrélées entre elles et assez nombreuses dans le dataset)*
#
# ---------------------

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('market_data_pd.csv',sep = ',')

# %%
df = df.drop(columns=['Unnamed: 0','Issuer Name','Maturity','Ask Price', 'Mid Price','Bid Price','Ticker','Reference Security','Cpn'])

# %%
df.head()
#potentielles variables explicatives, et variable expliquée : PD_1y
# Out:
#    Average Equity / Average Assets  Common Eqty / Tot Assets  \
# 0                          4.73005                   4.84431
# 1                         18.91500                  17.15800
# 2                         18.91500                  17.15800
# 3                         18.77330                  19.24570
# 4                         18.77330                  19.24570
#
#    Debt / Common Equity  Debt/Assets  Debt/EBITDA  EBITDA  \
# 0               684.499      33.1593          NaN     NaN
# 1               351.535      60.3164      1.61252  70.221
# 2               351.535      60.3164      1.61252  70.221
# 3               410.513      79.0061          NaN     NaN
# 4               410.513      79.0061          NaN     NaN
#
#    Int Exp / Avg Int Bear Liab  Tot Debt / Tot Capital  \
# 0                          NaN                 87.2526
# 1                          NaN                 77.8533
# 2                          NaN                 77.8533
# 3                      3.78296                 80.4119
# 4                      3.78296                 80.4119
#
#    Tot Loans to Tot Assets  Tot Risk-Based Cap  ...  Conversion Ratio  \
# 0                  72.7382               275.5  ...               NaN
# 1                      NaN                 NaN  ...               NaN
# 2                      NaN                 NaN  ...               NaN
# 3                      NaN                 NaN  ...               NaN
# 4                      NaN                 NaN  ...               NaN
#
#    Cntry of Incorp  Interest Coverage Ratio Lev Ratio to TCE  \
# 0               FI                      NaN              4.2
# 1               FR                 0.857497              NaN
# 2               FR                 0.857497              NaN
# 3               GB                      NaN              NaN
# 4               GB                      NaN              NaN
#
#   US SEC Reg Exmptn Risk-Based Cap Ratio State of Incorp  TCE Ratio  \
# 0               NaN                 16.5             NaN    4.45822
# 1               NaN                  NaN             NaN -171.02700
# 2               NaN                  NaN             NaN -171.02700
# 3               NaN                  NaN             NaN        NaN
# 4               NaN                  NaN             NaN        NaN
#
#   Tender Expiration Date  Tier-1 Ratio
# 0                    NaN          14.3
# 1                    NaN           NaN
# 2                    NaN           NaN
# 3             09/15/2020           NaN
# 4                    NaN           NaN
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (564, 27)

# %%
df.isnull().sum(axis = 0)
# Out:
# Average Equity / Average Assets              37
# Common Eqty / Tot Assets                     28
# Debt / Common Equity                         52
# Debt/Assets                                  29
# Debt/EBITDA                                 290
# EBITDA                                      222
# Int Exp / Avg Int Bear Liab                 469
# Tot Debt / Tot Capital                       30
# Tot Loans to Tot Assets                     399
# Tot Risk-Based Cap                          421
# Earnings Assets / Int Bear Liab             413
# Total Expenses to Average Earning Assets    560
# PD_1y                                         6
# BCLASS Level 1                                0
# BCLASS Level 2                                0
# BCLASS Level 3                                0
# BCLASS Level 4                                0
# Conversion Ratio                            550
# Cntry of Incorp                               0
# Interest Coverage Ratio                     271
# Lev Ratio to TCE                            447
# US SEC Reg Exmptn                           526
# Risk-Based Cap Ratio                        421
# State of Incorp                             501
# TCE Ratio                                    36
# Tender Expiration Date                      535
# Tier-1 Ratio                                424
# dtype: int64

# %% [markdown]
# On distingue dans ce notebook les variables quantitatives (*partie I*) et les variables qualitatives (*partie II*). Les tests d'indépendance de ces variables sont différents.
#
#
# # I. VARIABLES QUANTITATIVES
#
# # Observations des corrélations

# %%
corr_df = df.corr(method='spearman')
print("The correlation DataFrame is:")
print(corr_df, "\n")
# Out:
# The correlation DataFrame is:
#                                           Average Equity / Average Assets  \
# Average Equity / Average Assets                                  1.000000
# Common Eqty / Tot Assets                                         0.989120
# Debt / Common Equity                                            -0.679891
# Debt/Assets                                                      0.013776
# Debt/EBITDA                                                     -0.293401
# EBITDA                                                           0.110974
# Int Exp / Avg Int Bear Liab                                     -0.166309
# Tot Debt / Tot Capital                                          -0.715943
# Tot Loans to Tot Assets                                          0.593693
# Tot Risk-Based Cap                                              -0.234662
# Earnings Assets / Int Bear Liab                                 -0.339317
# Total Expenses to Average Earning Assets                              NaN
# PD_1y                                                           -0.124847
# Conversion Ratio                                                -0.007018
# Interest Coverage Ratio                                          0.369290
# Lev Ratio to TCE                                                 0.932112
# Risk-Based Cap Ratio                                            -0.293048
# TCE Ratio                                                        0.408501
# Tier-1 Ratio                                                     0.215017
#
#                                           Common Eqty / Tot Assets  \
# Average Equity / Average Assets                           0.989120
# Common Eqty / Tot Assets                                  1.000000
# Debt / Common Equity                                     -0.679272
# Debt/Assets                                              -0.004288
# Debt/EBITDA                                              -0.313084
# EBITDA                                                    0.136496
# Int Exp / Avg Int Bear Liab                              -0.150913
# Tot Debt / Tot Capital                                   -0.717151
# Tot Loans to Tot Assets                                   0.604967
# Tot Risk-Based Cap                                       -0.251891
# Earnings Assets / Int Bear Liab                          -0.337838
# Total Expenses to Average Earning Assets                       NaN
# PD_1y                                                    -0.149575
# Conversion Ratio                                         -0.021053
# Interest Coverage Ratio                                   0.408858
# Lev Ratio to TCE                                          0.924829
# Risk-Based Cap Ratio                                     -0.320756
# TCE Ratio                                                 0.432786
# Tier-1 Ratio                                              0.175193
#
#                                           Debt / Common Equity  Debt/Assets  \
# Average Equity / Average Assets                      -0.679891     0.013776
# Common Eqty / Tot Assets                             -0.679272    -0.004288
# Debt / Common Equity                                  1.000000     0.497984
# Debt/Assets                                           0.497984     1.000000
# Debt/EBITDA                                           0.480710     0.478818
# EBITDA                                               -0.109385    -0.233379
# Int Exp / Avg Int Bear Liab                           0.316698     0.489975
# Tot Debt / Tot Capital                                0.991394     0.530687
# Tot Loans to Tot Assets                              -0.317878     0.548645
# Tot Risk-Based Cap                                   -0.083990    -0.532496
# Earnings Assets / Int Bear Liab                       0.219980    -0.238857
# Total Expenses to Average Earning Assets                   NaN          NaN
# PD_1y                                                -0.080543     0.005642
# Conversion Ratio                                      0.314352    -0.126316
# Interest Coverage Ratio                              -0.427377    -0.358170
# Lev Ratio to TCE                                     -0.614940     0.432164
# Risk-Based Cap Ratio                                  0.284739    -0.018332
# TCE Ratio                                            -0.378712    -0.225222
# Tier-1 Ratio                                         -0.070022     0.173043
#
#                                           Debt/EBITDA    EBITDA  \
# Average Equity / Average Assets             -0.293401  0.110974
# Common Eqty / Tot Assets                    -0.313084  0.136496
# Debt / Common Equity                         0.480710 -0.109385
# Debt/Assets                                  0.478818 -0.233379
# Debt/EBITDA                                  1.000000 -0.394820
# EBITDA                                      -0.394820  1.000000
# Int Exp / Avg Int Bear Liab                  0.856492  0.419162
# Tot Debt / Tot Capital                       0.447813 -0.174138
# Tot Loans to Tot Assets                     -1.000000 -0.221477
# Tot Risk-Based Cap                                NaN  0.980861
# Earnings Assets / Int Bear Liab              0.220339  0.019827
# Total Expenses to Average Earning Assets          NaN       NaN
# PD_1y                                        0.423564 -0.483613
# Conversion Ratio                            -0.058578  0.435088
# Interest Coverage Ratio                     -0.560524  0.524713
# Lev Ratio to TCE                                  NaN  0.980861
# Risk-Based Cap Ratio                              NaN -1.000000
# TCE Ratio                                   -0.124098 -0.040813
# Tier-1 Ratio                                      NaN -0.980861
#
#                                           Int Exp / Avg Int Bear Liab  \
# Average Equity / Average Assets                             -0.166309
# Common Eqty / Tot Assets                                    -0.150913
# Debt / Common Equity                                         0.316698
# Debt/Assets                                                  0.489975
# Debt/EBITDA                                                  0.856492
# EBITDA                                                       0.419162
# Int Exp / Avg Int Bear Liab                                  1.000000
# Tot Debt / Tot Capital                                       0.357327
# Tot Loans to Tot Assets                                      0.552088
# Tot Risk-Based Cap                                          -0.444759
# Earnings Assets / Int Bear Liab                              0.022964
# Total Expenses to Average Earning Assets                          NaN
# PD_1y                                                        0.217899
# Conversion Ratio                                                  NaN
# Interest Coverage Ratio                                           NaN
# Lev Ratio to TCE                                            -0.429308
# Risk-Based Cap Ratio                                         0.366682
# TCE Ratio                                                   -0.398796
# Tier-1 Ratio                                                 0.262855
#
#                                           Tot Debt / Tot Capital  \
# Average Equity / Average Assets                        -0.715943
# Common Eqty / Tot Assets                               -0.717151
# Debt / Common Equity                                    0.991394
# Debt/Assets                                             0.530687
# Debt/EBITDA                                             0.447813
# EBITDA                                                 -0.174138
# Int Exp / Avg Int Bear Liab                             0.357327
# Tot Debt / Tot Capital                                  1.000000
# Tot Loans to Tot Assets                                -0.265172
# Tot Risk-Based Cap                                     -0.178671
# Earnings Assets / Int Bear Liab                         0.192789
# Total Expenses to Average Earning Assets                     NaN
# PD_1y                                                  -0.009905
# Conversion Ratio                                        0.035088
# Interest Coverage Ratio                                -0.431914
# Lev Ratio to TCE                                       -0.614940
# Risk-Based Cap Ratio                                    0.255656
# TCE Ratio                                              -0.397195
# Tier-1 Ratio                                           -0.094289
#
#                                           Tot Loans to Tot Assets  \
# Average Equity / Average Assets                          0.593693
# Common Eqty / Tot Assets                                 0.604967
# Debt / Common Equity                                    -0.317878
# Debt/Assets                                              0.548645
# Debt/EBITDA                                             -1.000000
# EBITDA                                                  -0.221477
# Int Exp / Avg Int Bear Liab                              0.552088
# Tot Debt / Tot Capital                                  -0.265172
# Tot Loans to Tot Assets                                  1.000000
# Tot Risk-Based Cap                                      -0.563254
# Earnings Assets / Int Bear Liab                         -0.339843
# Total Expenses to Average Earning Assets                      NaN
# PD_1y                                                    0.054198
# Conversion Ratio                                              NaN
# Interest Coverage Ratio                                       NaN
# Lev Ratio to TCE                                         0.699155
# Risk-Based Cap Ratio                                    -0.020173
# TCE Ratio                                                0.614671
# Tier-1 Ratio                                             0.387068
#
#                                           Tot Risk-Based Cap  \
# Average Equity / Average Assets                    -0.234662
# Common Eqty / Tot Assets                           -0.251891
# Debt / Common Equity                               -0.083990
# Debt/Assets                                        -0.532496
# Debt/EBITDA                                              NaN
# EBITDA                                              0.980861
# Int Exp / Avg Int Bear Liab                        -0.444759
# Tot Debt / Tot Capital                             -0.178671
# Tot Loans to Tot Assets                            -0.563254
# Tot Risk-Based Cap                                  1.000000
# Earnings Assets / Int Bear Liab                     0.225448
# Total Expenses to Average Earning Assets                 NaN
# PD_1y                                              -0.101793
# Conversion Ratio                                         NaN
# Interest Coverage Ratio                                  NaN
# Lev Ratio to TCE                                   -0.120563
# Risk-Based Cap Ratio                               -0.109990
# TCE Ratio                                          -0.230752
# Tier-1 Ratio                                       -0.357656
#
#                                           Earnings Assets / Int Bear Liab  \
# Average Equity / Average Assets                                 -0.339317
# Common Eqty / Tot Assets                                        -0.337838
# Debt / Common Equity                                             0.219980
# Debt/Assets                                                     -0.238857
# Debt/EBITDA                                                      0.220339
# EBITDA                                                           0.019827
# Int Exp / Avg Int Bear Liab                                      0.022964
# Tot Debt / Tot Capital                                           0.192789
# Tot Loans to Tot Assets                                         -0.339843
# Tot Risk-Based Cap                                               0.225448
# Earnings Assets / Int Bear Liab                                  1.000000
# Total Expenses to Average Earning Assets                              NaN
# PD_1y                                                            0.340083
# Conversion Ratio                                                      NaN
# Interest Coverage Ratio                                               NaN
# Lev Ratio to TCE                                                -0.606590
# Risk-Based Cap Ratio                                            -0.159610
# TCE Ratio                                                       -0.320865
# Tier-1 Ratio                                                    -0.283426
#
#                                           Total Expenses to Average Earning Assets  \
# Average Equity / Average Assets                                                NaN
# Common Eqty / Tot Assets                                                       NaN
# Debt / Common Equity                                                           NaN
# Debt/Assets                                                                    NaN
# Debt/EBITDA                                                                    NaN
# EBITDA                                                                         NaN
# Int Exp / Avg Int Bear Liab                                                    NaN
# Tot Debt / Tot Capital                                                         NaN
# Tot Loans to Tot Assets                                                        NaN
# Tot Risk-Based Cap                                                             NaN
# Earnings Assets / Int Bear Liab                                                NaN
# Total Expenses to Average Earning Assets                                       NaN
# PD_1y                                                                          NaN
# Conversion Ratio                                                               NaN
# Interest Coverage Ratio                                                        NaN
# Lev Ratio to TCE                                                               NaN
# Risk-Based Cap Ratio                                                           NaN
# TCE Ratio                                                                      NaN
# Tier-1 Ratio                                                                   NaN
#
#                                              PD_1y  Conversion Ratio  \
# Average Equity / Average Assets          -0.124847         -0.007018
# Common Eqty / Tot Assets                 -0.149575         -0.021053
# Debt / Common Equity                     -0.080543          0.314352
# Debt/Assets                               0.005642         -0.126316
# Debt/EBITDA                               0.423564         -0.058578
# EBITDA                                   -0.483613          0.435088
# Int Exp / Avg Int Bear Liab               0.217899               NaN
# Tot Debt / Tot Capital                   -0.009905          0.035088
# Tot Loans to Tot Assets                   0.054198               NaN
# Tot Risk-Based Cap                       -0.101793               NaN
# Earnings Assets / Int Bear Liab           0.340083               NaN
# Total Expenses to Average Earning Assets       NaN               NaN
# PD_1y                                     1.000000         -0.173867
# Conversion Ratio                         -0.173867          1.000000
# Interest Coverage Ratio                  -0.402216          0.442105
# Lev Ratio to TCE                          0.007947               NaN
# Risk-Based Cap Ratio                     -0.138376               NaN
# TCE Ratio                                -0.100448          0.178947
# Tier-1 Ratio                              0.032277               NaN
#
#                                           Interest Coverage Ratio  \
# Average Equity / Average Assets                          0.369290
# Common Eqty / Tot Assets                                 0.408858
# Debt / Common Equity                                    -0.427377
# Debt/Assets                                             -0.358170
# Debt/EBITDA                                             -0.560524
# EBITDA                                                   0.524713
# Int Exp / Avg Int Bear Liab                                   NaN
# Tot Debt / Tot Capital                                  -0.431914
# Tot Loans to Tot Assets                                       NaN
# Tot Risk-Based Cap                                            NaN
# Earnings Assets / Int Bear Liab                               NaN
# Total Expenses to Average Earning Assets                      NaN
# PD_1y                                                   -0.402216
# Conversion Ratio                                         0.442105
# Interest Coverage Ratio                                  1.000000
# Lev Ratio to TCE                                              NaN
# Risk-Based Cap Ratio                                          NaN
# TCE Ratio                                                0.349574
# Tier-1 Ratio                                                  NaN
#
#                                           Lev Ratio to TCE  \
# Average Equity / Average Assets                   0.932112
# Common Eqty / Tot Assets                          0.924829
# Debt / Common Equity                             -0.614940
# Debt/Assets                                       0.432164
# Debt/EBITDA                                            NaN
# EBITDA                                            0.980861
# Int Exp / Avg Int Bear Liab                      -0.429308
# Tot Debt / Tot Capital                           -0.614940
# Tot Loans to Tot Assets                           0.699155
# Tot Risk-Based Cap                               -0.120563
# Earnings Assets / Int Bear Liab                  -0.606590
# Total Expenses to Average Earning Assets               NaN
# PD_1y                                             0.007947
# Conversion Ratio                                       NaN
# Interest Coverage Ratio                                NaN
# Lev Ratio to TCE                                  1.000000
# Risk-Based Cap Ratio                             -0.400709
# TCE Ratio                                         0.937094
# Tier-1 Ratio                                      0.132229
#
#                                           Risk-Based Cap Ratio  TCE Ratio  \
# Average Equity / Average Assets                      -0.293048   0.408501
# Common Eqty / Tot Assets                             -0.320756   0.432786
# Debt / Common Equity                                  0.284739  -0.378712
# Debt/Assets                                          -0.018332  -0.225222
# Debt/EBITDA                                                NaN  -0.124098
# EBITDA                                               -1.000000  -0.040813
# Int Exp / Avg Int Bear Liab                           0.366682  -0.398796
# Tot Debt / Tot Capital                                0.255656  -0.397195
# Tot Loans to Tot Assets                              -0.020173   0.614671
# Tot Risk-Based Cap                                   -0.109990  -0.230752
# Earnings Assets / Int Bear Liab                      -0.159610  -0.320865
# Total Expenses to Average Earning Assets                   NaN        NaN
# PD_1y                                                -0.138376  -0.100448
# Conversion Ratio                                           NaN   0.178947
# Interest Coverage Ratio                                    NaN   0.349574
# Lev Ratio to TCE                                     -0.400709   0.937094
# Risk-Based Cap Ratio                                  1.000000  -0.288213
# TCE Ratio                                            -0.288213   1.000000
# Tier-1 Ratio                                          0.792351   0.190334
#
#                                           Tier-1 Ratio
# Average Equity / Average Assets               0.215017
# Common Eqty / Tot Assets                      0.175193
# Debt / Common Equity                         -0.070022
# Debt/Assets                                   0.173043
# Debt/EBITDA                                        NaN
# EBITDA                                       -0.980861
# Int Exp / Avg Int Bear Liab                   0.262855
# Tot Debt / Tot Capital                       -0.094289
# Tot Loans to Tot Assets                       0.387068
# Tot Risk-Based Cap                           -0.357656
# Earnings Assets / Int Bear Liab              -0.283426
# Total Expenses to Average Earning Assets           NaN
# PD_1y                                         0.032277
# Conversion Ratio                                   NaN
# Interest Coverage Ratio                            NaN
# Lev Ratio to TCE                              0.132229
# Risk-Based Cap Ratio                          0.792351
# TCE Ratio                                     0.190334
# Tier-1 Ratio                                  1.000000

# %%
corr = abs(corr_df)

# %%
corr
# Out:
#                                           Average Equity / Average Assets  \
# Average Equity / Average Assets                                  1.000000
# Common Eqty / Tot Assets                                         0.989120
# Debt / Common Equity                                             0.679891
# Debt/Assets                                                      0.013776
# Debt/EBITDA                                                      0.293401
# EBITDA                                                           0.110974
# Int Exp / Avg Int Bear Liab                                      0.166309
# Tot Debt / Tot Capital                                           0.715943
# Tot Loans to Tot Assets                                          0.593693
# Tot Risk-Based Cap                                               0.234662
# Earnings Assets / Int Bear Liab                                  0.339317
# Total Expenses to Average Earning Assets                              NaN
# PD_1y                                                            0.124847
# Conversion Ratio                                                 0.007018
# Interest Coverage Ratio                                          0.369290
# Lev Ratio to TCE                                                 0.932112
# Risk-Based Cap Ratio                                             0.293048
# TCE Ratio                                                        0.408501
# Tier-1 Ratio                                                     0.215017
#
#                                           Common Eqty / Tot Assets  \
# Average Equity / Average Assets                           0.989120
# Common Eqty / Tot Assets                                  1.000000
# Debt / Common Equity                                      0.679272
# Debt/Assets                                               0.004288
# Debt/EBITDA                                               0.313084
# EBITDA                                                    0.136496
# Int Exp / Avg Int Bear Liab                               0.150913
# Tot Debt / Tot Capital                                    0.717151
# Tot Loans to Tot Assets                                   0.604967
# Tot Risk-Based Cap                                        0.251891
# Earnings Assets / Int Bear Liab                           0.337838
# Total Expenses to Average Earning Assets                       NaN
# PD_1y                                                     0.149575
# Conversion Ratio                                          0.021053
# Interest Coverage Ratio                                   0.408858
# Lev Ratio to TCE                                          0.924829
# Risk-Based Cap Ratio                                      0.320756
# TCE Ratio                                                 0.432786
# Tier-1 Ratio                                              0.175193
#
#                                           Debt / Common Equity  Debt/Assets  \
# Average Equity / Average Assets                       0.679891     0.013776
# Common Eqty / Tot Assets                              0.679272     0.004288
# Debt / Common Equity                                  1.000000     0.497984
# Debt/Assets                                           0.497984     1.000000
# Debt/EBITDA                                           0.480710     0.478818
# EBITDA                                                0.109385     0.233379
# Int Exp / Avg Int Bear Liab                           0.316698     0.489975
# Tot Debt / Tot Capital                                0.991394     0.530687
# Tot Loans to Tot Assets                               0.317878     0.548645
# Tot Risk-Based Cap                                    0.083990     0.532496
# Earnings Assets / Int Bear Liab                       0.219980     0.238857
# Total Expenses to Average Earning Assets                   NaN          NaN
# PD_1y                                                 0.080543     0.005642
# Conversion Ratio                                      0.314352     0.126316
# Interest Coverage Ratio                               0.427377     0.358170
# Lev Ratio to TCE                                      0.614940     0.432164
# Risk-Based Cap Ratio                                  0.284739     0.018332
# TCE Ratio                                             0.378712     0.225222
# Tier-1 Ratio                                          0.070022     0.173043
#
#                                           Debt/EBITDA    EBITDA  \
# Average Equity / Average Assets              0.293401  0.110974
# Common Eqty / Tot Assets                     0.313084  0.136496
# Debt / Common Equity                         0.480710  0.109385
# Debt/Assets                                  0.478818  0.233379
# Debt/EBITDA                                  1.000000  0.394820
# EBITDA                                       0.394820  1.000000
# Int Exp / Avg Int Bear Liab                  0.856492  0.419162
# Tot Debt / Tot Capital                       0.447813  0.174138
# Tot Loans to Tot Assets                      1.000000  0.221477
# Tot Risk-Based Cap                                NaN  0.980861
# Earnings Assets / Int Bear Liab              0.220339  0.019827
# Total Expenses to Average Earning Assets          NaN       NaN
# PD_1y                                        0.423564  0.483613
# Conversion Ratio                             0.058578  0.435088
# Interest Coverage Ratio                      0.560524  0.524713
# Lev Ratio to TCE                                  NaN  0.980861
# Risk-Based Cap Ratio                              NaN  1.000000
# TCE Ratio                                    0.124098  0.040813
# Tier-1 Ratio                                      NaN  0.980861
#
#                                           Int Exp / Avg Int Bear Liab  \
# Average Equity / Average Assets                              0.166309
# Common Eqty / Tot Assets                                     0.150913
# Debt / Common Equity                                         0.316698
# Debt/Assets                                                  0.489975
# Debt/EBITDA                                                  0.856492
# EBITDA                                                       0.419162
# Int Exp / Avg Int Bear Liab                                  1.000000
# Tot Debt / Tot Capital                                       0.357327
# Tot Loans to Tot Assets                                      0.552088
# Tot Risk-Based Cap                                           0.444759
# Earnings Assets / Int Bear Liab                              0.022964
# Total Expenses to Average Earning Assets                          NaN
# PD_1y                                                        0.217899
# Conversion Ratio                                                  NaN
# Interest Coverage Ratio                                           NaN
# Lev Ratio to TCE                                             0.429308
# Risk-Based Cap Ratio                                         0.366682
# TCE Ratio                                                    0.398796
# Tier-1 Ratio                                                 0.262855
#
#                                           Tot Debt / Tot Capital  \
# Average Equity / Average Assets                         0.715943
# Common Eqty / Tot Assets                                0.717151
# Debt / Common Equity                                    0.991394
# Debt/Assets                                             0.530687
# Debt/EBITDA                                             0.447813
# EBITDA                                                  0.174138
# Int Exp / Avg Int Bear Liab                             0.357327
# Tot Debt / Tot Capital                                  1.000000
# Tot Loans to Tot Assets                                 0.265172
# Tot Risk-Based Cap                                      0.178671
# Earnings Assets / Int Bear Liab                         0.192789
# Total Expenses to Average Earning Assets                     NaN
# PD_1y                                                   0.009905
# Conversion Ratio                                        0.035088
# Interest Coverage Ratio                                 0.431914
# Lev Ratio to TCE                                        0.614940
# Risk-Based Cap Ratio                                    0.255656
# TCE Ratio                                               0.397195
# Tier-1 Ratio                                            0.094289
#
#                                           Tot Loans to Tot Assets  \
# Average Equity / Average Assets                          0.593693
# Common Eqty / Tot Assets                                 0.604967
# Debt / Common Equity                                     0.317878
# Debt/Assets                                              0.548645
# Debt/EBITDA                                              1.000000
# EBITDA                                                   0.221477
# Int Exp / Avg Int Bear Liab                              0.552088
# Tot Debt / Tot Capital                                   0.265172
# Tot Loans to Tot Assets                                  1.000000
# Tot Risk-Based Cap                                       0.563254
# Earnings Assets / Int Bear Liab                          0.339843
# Total Expenses to Average Earning Assets                      NaN
# PD_1y                                                    0.054198
# Conversion Ratio                                              NaN
# Interest Coverage Ratio                                       NaN
# Lev Ratio to TCE                                         0.699155
# Risk-Based Cap Ratio                                     0.020173
# TCE Ratio                                                0.614671
# Tier-1 Ratio                                             0.387068
#
#                                           Tot Risk-Based Cap  \
# Average Equity / Average Assets                     0.234662
# Common Eqty / Tot Assets                            0.251891
# Debt / Common Equity                                0.083990
# Debt/Assets                                         0.532496
# Debt/EBITDA                                              NaN
# EBITDA                                              0.980861
# Int Exp / Avg Int Bear Liab                         0.444759
# Tot Debt / Tot Capital                              0.178671
# Tot Loans to Tot Assets                             0.563254
# Tot Risk-Based Cap                                  1.000000
# Earnings Assets / Int Bear Liab                     0.225448
# Total Expenses to Average Earning Assets                 NaN
# PD_1y                                               0.101793
# Conversion Ratio                                         NaN
# Interest Coverage Ratio                                  NaN
# Lev Ratio to TCE                                    0.120563
# Risk-Based Cap Ratio                                0.109990
# TCE Ratio                                           0.230752
# Tier-1 Ratio                                        0.357656
#
#                                           Earnings Assets / Int Bear Liab  \
# Average Equity / Average Assets                                  0.339317
# Common Eqty / Tot Assets                                         0.337838
# Debt / Common Equity                                             0.219980
# Debt/Assets                                                      0.238857
# Debt/EBITDA                                                      0.220339
# EBITDA                                                           0.019827
# Int Exp / Avg Int Bear Liab                                      0.022964
# Tot Debt / Tot Capital                                           0.192789
# Tot Loans to Tot Assets                                          0.339843
# Tot Risk-Based Cap                                               0.225448
# Earnings Assets / Int Bear Liab                                  1.000000
# Total Expenses to Average Earning Assets                              NaN
# PD_1y                                                            0.340083
# Conversion Ratio                                                      NaN
# Interest Coverage Ratio                                               NaN
# Lev Ratio to TCE                                                 0.606590
# Risk-Based Cap Ratio                                             0.159610
# TCE Ratio                                                        0.320865
# Tier-1 Ratio                                                     0.283426
#
#                                           Total Expenses to Average Earning Assets  \
# Average Equity / Average Assets                                                NaN
# Common Eqty / Tot Assets                                                       NaN
# Debt / Common Equity                                                           NaN
# Debt/Assets                                                                    NaN
# Debt/EBITDA                                                                    NaN
# EBITDA                                                                         NaN
# Int Exp / Avg Int Bear Liab                                                    NaN
# Tot Debt / Tot Capital                                                         NaN
# Tot Loans to Tot Assets                                                        NaN
# Tot Risk-Based Cap                                                             NaN
# Earnings Assets / Int Bear Liab                                                NaN
# Total Expenses to Average Earning Assets                                       NaN
# PD_1y                                                                          NaN
# Conversion Ratio                                                               NaN
# Interest Coverage Ratio                                                        NaN
# Lev Ratio to TCE                                                               NaN
# Risk-Based Cap Ratio                                                           NaN
# TCE Ratio                                                                      NaN
# Tier-1 Ratio                                                                   NaN
#
#                                              PD_1y  Conversion Ratio  \
# Average Equity / Average Assets           0.124847          0.007018
# Common Eqty / Tot Assets                  0.149575          0.021053
# Debt / Common Equity                      0.080543          0.314352
# Debt/Assets                               0.005642          0.126316
# Debt/EBITDA                               0.423564          0.058578
# EBITDA                                    0.483613          0.435088
# Int Exp / Avg Int Bear Liab               0.217899               NaN
# Tot Debt / Tot Capital                    0.009905          0.035088
# Tot Loans to Tot Assets                   0.054198               NaN
# Tot Risk-Based Cap                        0.101793               NaN
# Earnings Assets / Int Bear Liab           0.340083               NaN
# Total Expenses to Average Earning Assets       NaN               NaN
# PD_1y                                     1.000000          0.173867
# Conversion Ratio                          0.173867          1.000000
# Interest Coverage Ratio                   0.402216          0.442105
# Lev Ratio to TCE                          0.007947               NaN
# Risk-Based Cap Ratio                      0.138376               NaN
# TCE Ratio                                 0.100448          0.178947
# Tier-1 Ratio                              0.032277               NaN
#
#                                           Interest Coverage Ratio  \
# Average Equity / Average Assets                          0.369290
# Common Eqty / Tot Assets                                 0.408858
# Debt / Common Equity                                     0.427377
# Debt/Assets                                              0.358170
# Debt/EBITDA                                              0.560524
# EBITDA                                                   0.524713
# Int Exp / Avg Int Bear Liab                                   NaN
# Tot Debt / Tot Capital                                   0.431914
# Tot Loans to Tot Assets                                       NaN
# Tot Risk-Based Cap                                            NaN
# Earnings Assets / Int Bear Liab                               NaN
# Total Expenses to Average Earning Assets                      NaN
# PD_1y                                                    0.402216
# Conversion Ratio                                         0.442105
# Interest Coverage Ratio                                  1.000000
# Lev Ratio to TCE                                              NaN
# Risk-Based Cap Ratio                                          NaN
# TCE Ratio                                                0.349574
# Tier-1 Ratio                                                  NaN
#
#                                           Lev Ratio to TCE  \
# Average Equity / Average Assets                   0.932112
# Common Eqty / Tot Assets                          0.924829
# Debt / Common Equity                              0.614940
# Debt/Assets                                       0.432164
# Debt/EBITDA                                            NaN
# EBITDA                                            0.980861
# Int Exp / Avg Int Bear Liab                       0.429308
# Tot Debt / Tot Capital                            0.614940
# Tot Loans to Tot Assets                           0.699155
# Tot Risk-Based Cap                                0.120563
# Earnings Assets / Int Bear Liab                   0.606590
# Total Expenses to Average Earning Assets               NaN
# PD_1y                                             0.007947
# Conversion Ratio                                       NaN
# Interest Coverage Ratio                                NaN
# Lev Ratio to TCE                                  1.000000
# Risk-Based Cap Ratio                              0.400709
# TCE Ratio                                         0.937094
# Tier-1 Ratio                                      0.132229
#
#                                           Risk-Based Cap Ratio  TCE Ratio  \
# Average Equity / Average Assets                       0.293048   0.408501
# Common Eqty / Tot Assets                              0.320756   0.432786
# Debt / Common Equity                                  0.284739   0.378712
# Debt/Assets                                           0.018332   0.225222
# Debt/EBITDA                                                NaN   0.124098
# EBITDA                                                1.000000   0.040813
# Int Exp / Avg Int Bear Liab                           0.366682   0.398796
# Tot Debt / Tot Capital                                0.255656   0.397195
# Tot Loans to Tot Assets                               0.020173   0.614671
# Tot Risk-Based Cap                                    0.109990   0.230752
# Earnings Assets / Int Bear Liab                       0.159610   0.320865
# Total Expenses to Average Earning Assets                   NaN        NaN
# PD_1y                                                 0.138376   0.100448
# Conversion Ratio                                           NaN   0.178947
# Interest Coverage Ratio                                    NaN   0.349574
# Lev Ratio to TCE                                      0.400709   0.937094
# Risk-Based Cap Ratio                                  1.000000   0.288213
# TCE Ratio                                             0.288213   1.000000
# Tier-1 Ratio                                          0.792351   0.190334
#
#                                           Tier-1 Ratio
# Average Equity / Average Assets               0.215017
# Common Eqty / Tot Assets                      0.175193
# Debt / Common Equity                          0.070022
# Debt/Assets                                   0.173043
# Debt/EBITDA                                        NaN
# EBITDA                                        0.980861
# Int Exp / Avg Int Bear Liab                   0.262855
# Tot Debt / Tot Capital                        0.094289
# Tot Loans to Tot Assets                       0.387068
# Tot Risk-Based Cap                            0.357656
# Earnings Assets / Int Bear Liab               0.283426
# Total Expenses to Average Earning Assets           NaN
# PD_1y                                         0.032277
# Conversion Ratio                                   NaN
# Interest Coverage Ratio                            NaN
# Lev Ratio to TCE                              0.132229
# Risk-Based Cap Ratio                          0.792351
# TCE Ratio                                     0.190334
# Tier-1 Ratio                                  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, vmin=0.00, vmax=1,cmap='coolwarm')

plt.title('Matrice de corrélation des variables')
# Out:
# Text(0.5, 1.0, 'Matrice de corrélation des variables')

# %% [markdown]
# # Tests statistiques
#
# **3 tests identifiés : Pearson, Spearman et Kendall.**
#
# Hypothèse $H_0$ *:* $\rho = 0$ *(indépendance). VS* $H_1$ *:*  $\rho \ne 0$ *(non indépendance)*
#
# **p-value :** Si $\alpha_{obs} < \alpha_{seuil}$, on rejette l'hypothèse $H_0$ d'indépendance.
#
# $-$ **Pearson :** suppose que les échantillons suivent une loi normale *(limite de ce test)*. Relation linéaire.
#
# $-$ **Spearman & Kendall :** *ok* Relation monotone

# %%
from scipy import stats
from scipy.stats.stats import *

# %%
df.dtypes
# Out:
# Average Equity / Average Assets             float64
# Common Eqty / Tot Assets                    float64
# Debt / Common Equity                        float64
# Debt/Assets                                 float64
# Debt/EBITDA                                 float64
# EBITDA                                      float64
# Int Exp / Avg Int Bear Liab                 float64
# Tot Debt / Tot Capital                      float64
# Tot Loans to Tot Assets                     float64
# Tot Risk-Based Cap                          float64
# Earnings Assets / Int Bear Liab             float64
# Total Expenses to Average Earning Assets    float64
# PD_1y                                       float64
# BCLASS Level 1                               object
# BCLASS Level 2                               object
# BCLASS Level 3                               object
# BCLASS Level 4                               object
# Conversion Ratio                            float64
# Cntry of Incorp                              object
# Interest Coverage Ratio                     float64
# Lev Ratio to TCE                            float64
# US SEC Reg Exmptn                            object
# Risk-Based Cap Ratio                        float64
# State of Incorp                              object
# TCE Ratio                                   float64
# Tender Expiration Date                       object
# Tier-1 Ratio                                float64
# dtype: object

# %%
colonnes = ['Average Equity / Average Assets','Common Eqty / Tot Assets', 'Debt / Common Equity', 'Debt/Assets','Debt/EBITDA', 'EBITDA', 'Int Exp / Avg Int Bear Liab','Tot Debt / Tot Capital', 'Tot Loans to Tot Assets','Tot Risk-Based Cap', 'Earnings Assets / Int Bear Liab','Conversion Ratio','Interest Coverage Ratio','Lev Ratio to TCE','Risk-Based Cap Ratio','TCE Ratio','Tier-1 Ratio']

# %% [markdown]
# # I. Pertinence sur la variable à expliquer

# %%
corr2= df.corr(method='spearman')
corr2["PD_1y"]
# Out:
# Average Equity / Average Assets            -0.124847
# Common Eqty / Tot Assets                   -0.149575
# Debt / Common Equity                       -0.080543
# Debt/Assets                                 0.005642
# Debt/EBITDA                                 0.423564
# EBITDA                                     -0.483613
# Int Exp / Avg Int Bear Liab                 0.217899
# Tot Debt / Tot Capital                     -0.009905
# Tot Loans to Tot Assets                     0.054198
# Tot Risk-Based Cap                         -0.101793
# Earnings Assets / Int Bear Liab             0.340083
# Total Expenses to Average Earning Assets         NaN
# PD_1y                                       1.000000
# Conversion Ratio                           -0.173867
# Interest Coverage Ratio                    -0.402216
# Lev Ratio to TCE                            0.007947
# Risk-Based Cap Ratio                       -0.138376
# TCE Ratio                                  -0.100448
# Tier-1 Ratio                                0.032277
# Name: PD_1y, dtype: float64

# %% [markdown]
# ## a. Pearson

# %%
#PEARSON

print("TEST DE PEARSON")

for col in colonnes :
    
    print("###### \n ")
    
    df_bis = df[['PD_1y',col]].dropna(how = 'any') 
    
    print(col)
    print(stats.pearsonr(df_bis['PD_1y'],df_bis[col]))
# Out:
# TEST DE PEARSON
# ######
#
# Average Equity / Average Assets
# (-0.3491283287709447, 2.219323438059356e-16)
# ######
#
# Common Eqty / Tot Assets
# (-0.3892559613861258, 1.2795755555356566e-20)
# ######
#
# Debt / Common Equity
# (-0.05389819009755161, 0.22616718018888982)
# ######
#
# Debt/Assets
# (0.13484336387609577, 0.001881872923297435)
# ######
#
# Debt/EBITDA
# (0.03171816592022272, 0.6051898292609911)
# ######
#
# EBITDA
# (-0.07230297097956234, 0.18612575604135795)
# ######
#
# Int Exp / Avg Int Bear Liab
# (0.36653770732175817, 0.00025891205706244443)
# ######
#
# Tot Debt / Tot Capital
# (0.6145794595805796, 3.7308979583895713e-56)
# ######
#
# Tot Loans to Tot Assets
# (0.08170921232440245, 0.29679067953057525)
# ######
#
# Tot Risk-Based Cap
# (-0.15163374092045898, 0.07063299040805486)
# ######
#
# Earnings Assets / Int Bear Liab
# (0.16995167549948, 0.03695609336408882)
# ######
#
# Conversion Ratio
# (-0.1962583467424661, 0.5012945135854553)
# ######
#
# Interest Coverage Ratio
# (-0.14277170839341788, 0.015496479557116092)
# ######
#
# Lev Ratio to TCE
# (-0.025434525765726176, 0.7854631118576634)
# ######
#
# Risk-Based Cap Ratio
# (-0.1608077571336778, 0.055033785136708153)
# ######
#
# TCE Ratio
# (-0.04398166185048512, 0.3158900502436996)
# ######
#
# Tier-1 Ratio
# (-0.04805456051760408, 0.5728783767185314)

# %% [markdown]
# **Observation des p-values :** Average Equity / Average Assets (0%), Common Eqty / Tot Assets (0%), Debt/Assets (0%), Int Exp / Avg Int Bear Liab (0%), Tot Debt / Tot Capital (0%). Interest Coverage Ratio (2%)

# %% [markdown]
# ## b. Spearman

# %%
#SPEARMAN

print("TEST DE SPEARMAN")

for col in colonnes :
    
    
    print("###### \n ")
    df_bis = df[['PD_1y',col]].dropna(how = 'any') 
    
    print(col)
    print(stats.spearmanr(df_bis['PD_1y'],df_bis[col]))
# Out:
# TEST DE SPEARMAN
# ######
#
# Average Equity / Average Assets
# SpearmanrResult(correlation=-0.12484683074527402, pvalue=0.004317100309375164)
# ######
#
# Common Eqty / Tot Assets
# SpearmanrResult(correlation=-0.14957499104721608, pvalue=0.0005507039719549005)
# ######
#
# Debt / Common Equity
# SpearmanrResult(correlation=-0.0805428322105443, pvalue=0.07026055039473905)
# ######
#
# Debt/Assets
# SpearmanrResult(correlation=0.00564243923688007, pvalue=0.8969856470686852)
# ######
#
# Debt/EBITDA
# SpearmanrResult(correlation=0.42356360432932316, pvalue=4.306361039659545e-13)
# ######
#
# EBITDA
# SpearmanrResult(correlation=-0.4836129947731729, pvalue=4.251367347357586e-21)
# ######
#
# Int Exp / Avg Int Bear Liab
# SpearmanrResult(correlation=0.21789940600640206, pvalue=0.033899508701761526)
# ######
#
# Tot Debt / Tot Capital
# SpearmanrResult(correlation=-0.009905070866929579, pvalue=0.8203713684800578)
# ######
#
# Tot Loans to Tot Assets
# SpearmanrResult(correlation=0.054198315528015094, pvalue=0.4893105938830762)
# ######
#
# Tot Risk-Based Cap
# SpearmanrResult(correlation=-0.1017927206257616, pvalue=0.22638424630207143)
# ######
#
# Earnings Assets / Int Bear Liab
# SpearmanrResult(correlation=0.34008300173352984, pvalue=1.9343965323492956e-05)
# ######
#
# Conversion Ratio
# SpearmanrResult(correlation=-0.17386707399786158, pvalue=0.5522079460954347)
# ######
#
# Interest Coverage Ratio
# SpearmanrResult(correlation=-0.4022159649070139, pvalue=1.3830860336232757e-12)
# ######
#
# Lev Ratio to TCE
# SpearmanrResult(correlation=0.007947067800312643, pvalue=0.9322303154939747)
# ######
#
# Risk-Based Cap Ratio
# SpearmanrResult(correlation=-0.13837647929955288, pvalue=0.09932027706600273)
# ######
#
# TCE Ratio
# SpearmanrResult(correlation=-0.10044761595017096, pvalue=0.02171795309484525)
# ######
#
# Tier-1 Ratio
# SpearmanrResult(correlation=0.03227699665529326, pvalue=0.7049988276035208)

# %% [markdown]
# **Observations des p-values :** Average Equity / Average Assets (1%), Common Eqty / Tot Assets (0%), Debt / Common Equity (3%), Debt/EBITDA (0%), EBITDA (0%), Int Exp / Avg Int Bear Liab (6%), Earnings Assets / Int Bear Liab (0%). Interest Coverage Ratio (0%), TCE Ratio (2%)

# %% [markdown]
# ## c. Kendall

# %%
#KENDALL

print("TEST DE KENDALL")

for col in colonnes :
    
    print("###### \n ") 
    
    df_bis = df[['PD_1y',col]].dropna(how = 'any') 
    
    print(col)
    print(stats.kendalltau(df_bis['PD_1y'],df_bis[col]))
# Out:
# TEST DE KENDALL
# ######
#
# Average Equity / Average Assets
# KendalltauResult(correlation=-0.08565030312643929, pvalue=0.0036904536773398285)
# ######
#
# Common Eqty / Tot Assets
# KendalltauResult(correlation=-0.10282314962431573, pvalue=0.0004372424649366641)
# ######
#
# Debt / Common Equity
# KendalltauResult(correlation=-0.05395636099899739, pvalue=0.07159077522444474)
# ######
#
# Debt/Assets
# KendalltauResult(correlation=0.00810980570622901, pvalue=0.7817294053123971)
# ######
#
# Debt/EBITDA
# KendalltauResult(correlation=0.2923987362597523, pvalue=1.4405215197678771e-12)
# ######
#
# EBITDA
# KendalltauResult(correlation=-0.33776527120891353, pvalue=4.540259250392481e-20)
# ######
#
# Int Exp / Avg Int Bear Liab
# KendalltauResult(correlation=0.14057408755964368, pvalue=0.05103517837523027)
# ######
#
# Tot Debt / Tot Capital
# KendalltauResult(correlation=-0.006092908563405727, pvalue=0.8352620318480196)
# ######
#
# Tot Loans to Tot Assets
# KendalltauResult(correlation=0.030737141144656095, pvalue=0.5724459509782464)
# ######
#
# Tot Risk-Based Cap
# KendalltauResult(correlation=-0.07924142928561342, pvalue=0.18041828983419772)
# ######
#
# Earnings Assets / Int Bear Liab
# KendalltauResult(correlation=0.24260889402432592, pvalue=2.247445354996109e-05)
# ######
#
# Conversion Ratio
# KendalltauResult(correlation=-0.13858697343671664, pvalue=0.5172777571151166)
# ######
#
# Interest Coverage Ratio
# KendalltauResult(correlation=-0.28055251396875663, pvalue=1.9859264178246623e-12)
# ######
#
# Lev Ratio to TCE
# KendalltauResult(correlation=0.0017602043645495488, pvalue=0.9789621807319572)
# ######
#
# Risk-Based Cap Ratio
# KendalltauResult(correlation=-0.10312037434038883, pvalue=0.08175213899729604)
# ######
#
# TCE Ratio
# KendalltauResult(correlation=-0.06581643534695444, pvalue=0.025525837997550094)
# ######
#
# Tier-1 Ratio
# KendalltauResult(correlation=0.027269488300609258, pvalue=0.6490398755372113)

# %% [markdown]
# **Observation des p-values :** Average Equity / Average Assets (2é%), Common Eqty / Tot Assets (0%), Debt / Common Equity (3%), Debt/EBITDA (0%), EBITDA (0%), Int Exp / Avg Int Bear Liab (10%), Earnings Assets / Int Bear Liab (0%). Interest Coverage Ratio (0%), TCE Ratio (2%).

# %% [markdown]
# **CONCLUSION**
#
# On compare les résultats des 3 tests. Les variables qu'on retient sont celles pour lesquelles on rejette l'hypothèse d'indépendance avec la variable expliquée, ie celles avec une p-value très faible.
#
#
# On choisit **Average Equity / Average Assets, Common Eqty / Tot Assets, Int Exp / Avg Int Bear Liab, Debt/EBITDA, EBITDA, Earnings Assets / Int Bear Liab, Debt / Common Equity, Interest Coverage Ratio, TCE Ratio**.

# %% [markdown]
# # II. Corrélations entre variables explicatives

# %%
var = df[["Average Equity / Average Assets","Common Eqty / Tot Assets","Debt/EBITDA","EBITDA","Earnings Assets / Int Bear Liab","Int Exp / Avg Int Bear Liab","Debt / Common Equity","Interest Coverage Ratio",'TCE Ratio','Risk-Based Cap Ratio']]

# %%
var
# Out:
#      Average Equity / Average Assets  Common Eqty / Tot Assets  Debt/EBITDA  \
# 0                            4.73005                   4.84431          NaN
# 1                           18.91500                  17.15800      1.61252
# 2                           18.91500                  17.15800      1.61252
# 3                           18.77330                  19.24570          NaN
# 4                           18.77330                  19.24570          NaN
# ..                               ...                       ...          ...
# 559                          5.36822                   5.32749     21.36510
# 560                          5.36822                   5.32749     21.36510
# 561                              NaN                 100.00000          NaN
# 562                          5.36822                   5.32749     21.36510
# 563                          5.36822                   5.32749     21.36510
#
#       EBITDA  Earnings Assets / Int Bear Liab  Int Exp / Avg Int Bear Liab  \
# 0        NaN                              NaN                          NaN
# 1     70.221                              NaN                          NaN
# 2     70.221                              NaN                          NaN
# 3        NaN                              NaN                      3.78296
# 4        NaN                              NaN                      3.78296
# ..       ...                              ...                          ...
# 559  912.000                          203.958                      3.35512
# 560  912.000                          203.958                      3.35512
# 561      NaN                              NaN                          NaN
# 562  912.000                          203.958                      3.35512
# 563  912.000                          203.958                      3.35512
#
#      Debt / Common Equity  Interest Coverage Ratio  TCE Ratio  \
# 0                 684.499                      NaN    4.45822
# 1                 351.535                 0.857497 -171.02700
# 2                 351.535                 0.857497 -171.02700
# 3                 410.513                      NaN        NaN
# 4                 410.513                      NaN        NaN
# ..                    ...                      ...        ...
# 559               774.751                      NaN    5.32749
# 560               774.751                      NaN    5.32749
# 561                 0.000                      NaN  100.00000
# 562               774.751                      NaN    5.32749
# 563               774.751                      NaN    5.32749
#
#      Risk-Based Cap Ratio
# 0                    16.5
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 559                   NaN
# 560                   NaN
# 561                   NaN
# 562                   NaN
# 563                   NaN
#
# [564 rows x 10 columns]

# %%
colonnes2 = ["Average Equity / Average Assets","Common Eqty / Tot Assets","Debt/EBITDA","EBITDA","Earnings Assets / Int Bear Liab","Int Exp / Avg Int Bear Liab","Debt / Common Equity","Interest Coverage Ratio",'TCE Ratio','Risk-Based Cap Ratio']

# %%
var.isnull().sum(axis = 0)
# Out:
# Average Equity / Average Assets     37
# Common Eqty / Tot Assets            28
# Debt/EBITDA                        290
# EBITDA                             222
# Earnings Assets / Int Bear Liab    413
# Int Exp / Avg Int Bear Liab        469
# Debt / Common Equity                52
# Interest Coverage Ratio            271
# TCE Ratio                           36
# Risk-Based Cap Ratio               421
# dtype: int64

# %% [markdown]
# Problème des valeurs manquantes : *Int Exp / Avg Int Bear Liab*, *Debt/EBITDA*, *Earnings Assets / Int Bear Liab*, *Interest Coverage Ratio*, *Risk-Based Cap Ratio* et *EBITDA* ont énormèment de valeurs manquantes. Cela sera problématique ensuite pour le réseau de neurones.

# %% [markdown]
# ## 1) en gardant toutes les variables

# %%
corr_var = var.corr(method='spearman')
print("The correlation DataFrame is:")
print(corr_var, "\n")
# Out:
# The correlation DataFrame is:
#                                  Average Equity / Average Assets  \
# Average Equity / Average Assets                         1.000000
# Common Eqty / Tot Assets                                0.989120
# Debt/EBITDA                                            -0.293401
# EBITDA                                                  0.110974
# Earnings Assets / Int Bear Liab                        -0.339317
# Int Exp / Avg Int Bear Liab                            -0.166309
# Debt / Common Equity                                   -0.679891
# Interest Coverage Ratio                                 0.369290
# TCE Ratio                                               0.408501
# Risk-Based Cap Ratio                                   -0.293048
#
#                                  Common Eqty / Tot Assets  Debt/EBITDA  \
# Average Equity / Average Assets                  0.989120    -0.293401
# Common Eqty / Tot Assets                         1.000000    -0.313084
# Debt/EBITDA                                     -0.313084     1.000000
# EBITDA                                           0.136496    -0.394820
# Earnings Assets / Int Bear Liab                 -0.337838     0.220339
# Int Exp / Avg Int Bear Liab                     -0.150913     0.856492
# Debt / Common Equity                            -0.679272     0.480710
# Interest Coverage Ratio                          0.408858    -0.560524
# TCE Ratio                                        0.432786    -0.124098
# Risk-Based Cap Ratio                            -0.320756          NaN
#
#                                    EBITDA  Earnings Assets / Int Bear Liab  \
# Average Equity / Average Assets  0.110974                        -0.339317
# Common Eqty / Tot Assets         0.136496                        -0.337838
# Debt/EBITDA                     -0.394820                         0.220339
# EBITDA                           1.000000                         0.019827
# Earnings Assets / Int Bear Liab  0.019827                         1.000000
# Int Exp / Avg Int Bear Liab      0.419162                         0.022964
# Debt / Common Equity            -0.109385                         0.219980
# Interest Coverage Ratio          0.524713                              NaN
# TCE Ratio                       -0.040813                        -0.320865
# Risk-Based Cap Ratio            -1.000000                        -0.159610
#
#                                  Int Exp / Avg Int Bear Liab  \
# Average Equity / Average Assets                    -0.166309
# Common Eqty / Tot Assets                           -0.150913
# Debt/EBITDA                                         0.856492
# EBITDA                                              0.419162
# Earnings Assets / Int Bear Liab                     0.022964
# Int Exp / Avg Int Bear Liab                         1.000000
# Debt / Common Equity                                0.316698
# Interest Coverage Ratio                                  NaN
# TCE Ratio                                          -0.398796
# Risk-Based Cap Ratio                                0.366682
#
#                                  Debt / Common Equity  \
# Average Equity / Average Assets             -0.679891
# Common Eqty / Tot Assets                    -0.679272
# Debt/EBITDA                                  0.480710
# EBITDA                                      -0.109385
# Earnings Assets / Int Bear Liab              0.219980
# Int Exp / Avg Int Bear Liab                  0.316698
# Debt / Common Equity                         1.000000
# Interest Coverage Ratio                     -0.427377
# TCE Ratio                                   -0.378712
# Risk-Based Cap Ratio                         0.284739
#
#                                  Interest Coverage Ratio  TCE Ratio  \
# Average Equity / Average Assets                 0.369290   0.408501
# Common Eqty / Tot Assets                        0.408858   0.432786
# Debt/EBITDA                                    -0.560524  -0.124098
# EBITDA                                          0.524713  -0.040813
# Earnings Assets / Int Bear Liab                      NaN  -0.320865
# Int Exp / Avg Int Bear Liab                          NaN  -0.398796
# Debt / Common Equity                           -0.427377  -0.378712
# Interest Coverage Ratio                         1.000000   0.349574
# TCE Ratio                                       0.349574   1.000000
# Risk-Based Cap Ratio                                 NaN  -0.288213
#
#                                  Risk-Based Cap Ratio
# Average Equity / Average Assets             -0.293048
# Common Eqty / Tot Assets                    -0.320756
# Debt/EBITDA                                       NaN
# EBITDA                                      -1.000000
# Earnings Assets / Int Bear Liab             -0.159610
# Int Exp / Avg Int Bear Liab                  0.366682
# Debt / Common Equity                         0.284739
# Interest Coverage Ratio                           NaN
# TCE Ratio                                   -0.288213
# Risk-Based Cap Ratio                         1.000000

# %%
sns.heatmap(corr_var, xticklabels=corr_var.columns, yticklabels=corr_var.columns, vmin=0.00, vmax=1,cmap='coolwarm')

plt.title('Matrice de corrélation des variables')
# Out:
# Text(0.5, 1.0, 'Matrice de corrélation des variables')

# %% [markdown]
# Doublon entre Common Eqty / Tot Aassets et Average Equity / Average Assets, et Int Exp / avg int bear liab et Debt/EBITDA.

# %% [markdown]
# ## a. Spearman

# %%
print("TEST DE SPEARMAN")

for col1 in colonnes2 :
    print("\n##############################\n")
    print("VAR = " + col1)
    for col2 in colonnes2 : 
        
        if col1 != col2 :
    
            df_bis = var[[col1,col2]].dropna(how = 'any') 
        
            print("----")
            print(col2)
            print(stats.spearmanr(df_bis[col1],df_bis[col2]))
# Out:
# TEST DE SPEARMAN
#
# ##############################
#
# VAR = Average Equity / Average Assets
# ----
# Common Eqty / Tot Assets
# SpearmanrResult(correlation=0.9891197656292327, pvalue=0.0)
# ----
# Debt/EBITDA
# SpearmanrResult(correlation=-0.29340050505477056, pvalue=8.820469754265955e-07)
# ----
# EBITDA
# SpearmanrResult(correlation=0.11097358523886208, pvalue=0.041453195176830715)
# ----
# Earnings Assets / Int Bear Liab
# SpearmanrResult(correlation=-0.3393166285336071, pvalue=2.3029490174197428e-05)
# ----
# Int Exp / Avg Int Bear Liab
# SpearmanrResult(correlation=-0.16630902047435925, pvalue=0.10723208382578449)
# ----
# Debt / Common Equity
# SpearmanrResult(correlation=-0.6798907470716684, pvalue=9.082212618557423e-70)
# ----
# Interest Coverage Ratio
# SpearmanrResult(correlation=0.3692904327117488, pvalue=9.09581888226256e-11)
# ----
# TCE Ratio
# SpearmanrResult(correlation=0.4085010030791034, pvalue=2.474524794654607e-22)
#
# ##############################
#
# VAR = Common Eqty / Tot Assets
# ----
# Average Equity / Average Assets
# SpearmanrResult(correlation=0.9891197656292327, pvalue=0.0)
# ----
# Debt/EBITDA
# SpearmanrResult(correlation=-0.3130843139749751, pvalue=1.2070480996713414e-07)
# ----
# EBITDA
# SpearmanrResult(correlation=0.136496331744181, pvalue=0.011508895416996621)
# ----
# Earnings Assets / Int Bear Liab
# SpearmanrResult(correlation=-0.337837981370088, pvalue=2.212009915174964e-05)
# ----
# Int Exp / Avg Int Bear Liab
# SpearmanrResult(correlation=-0.15091252894809526, pvalue=0.14434066881082924)
# ----
# Debt / Common Equity
# SpearmanrResult(correlation=-0.6792721971312254, pvalue=1.5333063133880598e-70)
# ----
# Interest Coverage Ratio
# SpearmanrResult(correlation=0.4088579619447129, pvalue=3.1066632121114724e-13)
# ----
# TCE Ratio
# SpearmanrResult(correlation=0.43278585357343524, pvalue=1.6316315687661184e-25)
#
# ##############################
#
# VAR = Debt/EBITDA
# ----
# Average Equity / Average Assets
# SpearmanrResult(correlation=-0.29340050505477056, pvalue=8.820469754265955e-07)
# ----
# Common Eqty / Tot Assets
# SpearmanrResult(correlation=-0.3130843139749751, pvalue=1.2070480996713414e-07)
# ----
# EBITDA
# SpearmanrResult(correlation=-0.39481969073163786, pvalue=1.176110745991289e-11)
# ----
# Earnings Assets / Int Bear Liab
# SpearmanrResult(correlation=0.22033898305084743, pvalue=0.4122085085395957)
# ----
# Int Exp / Avg Int Bear Liab
# SpearmanrResult(correlation=0.856492027334852, pvalue=5.708559536529737e-06)
# ----
# Debt / Common Equity
# SpearmanrResult(correlation=0.48071049214366074, pvalue=1.4830693642810132e-16)
# ----
# Interest Coverage Ratio
# SpearmanrResult(correlation=-0.560524407689745, pvalue=4.379545880476114e-22)
# ----
# TCE Ratio
# SpearmanrResult(correlation=-0.12409781163509274, pvalue=0.040098317504837715)
#
# ##############################
#
# VAR = EBITDA
# ----
# Average Equity / Average Assets
# SpearmanrResult(correlation=0.11097358523886208, pvalue=0.041453195176830715)
# ----
# Common Eqty / Tot Assets
# SpearmanrResult(correlation=0.136496331744181, pvalue=0.011508895416996621)
# ----
# Debt/EBITDA
# SpearmanrResult(correlation=-0.39481969073163786, pvalue=1.176110745991289e-11)
# ----
# Earnings Assets / Int Bear Liab
# SpearmanrResult(correlation=0.019826517967781905, pvalue=0.9059507007842822)
# ----
# Int Exp / Avg Int Bear Liab
# SpearmanrResult(correlation=0.41916167664670656, pvalue=0.05216369531330904)
# ----
# Debt / Common Equity
# SpearmanrResult(correlation=-0.10938543983640502, pvalue=0.0505879274392347)
# ----
# Interest Coverage Ratio
# SpearmanrResult(correlation=0.5247129315572323, pvalue=3.952251515968688e-22)
# ----
# TCE Ratio
# SpearmanrResult(correlation=-0.04081285367643418, pvalue=0.45186333050965355)
#
# ##############################
#
# VAR = Earnings Assets / Int Bear Liab
# ----
# Average Equity / Average Assets
# SpearmanrResult(correlation=-0.3393166285336071, pvalue=2.3029490174197428e-05)
# ----
# Common Eqty / Tot Assets
# SpearmanrResult(correlation=-0.337837981370088, pvalue=2.212009915174964e-05)
# ----
# Debt/EBITDA
# SpearmanrResult(correlation=0.22033898305084743, pvalue=0.4122085085395957)
# ----
# EBITDA
# SpearmanrResult(correlation=0.019826517967781905, pvalue=0.9059507007842822)
# ----
# Int Exp / Avg Int Bear Liab
# SpearmanrResult(correlation=0.022963706662679172, pvalue=0.8367411713750972)
# ----
# Debt / Common Equity
# SpearmanrResult(correlation=0.21998002070187672, pvalue=0.006833077833110406)
# ----
# Interest Coverage Ratio
# SpearmanrResult(correlation=nan, pvalue=nan)
# ----
# TCE Ratio
# SpearmanrResult(correlation=-0.3208650057178464, pvalue=5.898728815304911e-05)
#
# ##############################
#
# VAR = Int Exp / Avg Int Bear Liab
# ----
# Average Equity / Average Assets
# SpearmanrResult(correlation=-0.16630902047435925, pvalue=0.10723208382578449)
# ----
# Common Eqty / Tot Assets
# SpearmanrResult(correlation=-0.15091252894809526, pvalue=0.14434066881082924)
# ----
# Debt/EBITDA
# SpearmanrResult(correlation=0.856492027334852, pvalue=5.708559536529737e-06)
# ----
# EBITDA
# SpearmanrResult(correlation=0.41916167664670656, pvalue=0.05216369531330904)
# ----
# Earnings Assets / Int Bear Liab
# SpearmanrResult(correlation=0.022963706662679172, pvalue=0.8367411713750972)
# ----
# Debt / Common Equity
# SpearmanrResult(correlation=0.3166978703487011, pvalue=0.0018716353782787)
# ----
# Interest Coverage Ratio
# SpearmanrResult(correlation=nan, pvalue=nan)
# ----
# TCE Ratio
# SpearmanrResult(correlation=-0.39879631468513355, pvalue=0.00010842013137877283)
#
# ##############################
#
# VAR = Debt / Common Equity
# ----
# Average Equity / Average Assets
# SpearmanrResult(correlation=-0.6798907470716685, pvalue=9.082212618556906e-70)
# ----
# Common Eqty / Tot Assets
# SpearmanrResult(correlation=-0.6792721971312254, pvalue=1.5333063133880598e-70)
# ----
# Debt/EBITDA
# SpearmanrResult(correlation=0.48071049214366074, pvalue=1.4830693642810132e-16)
# ----
# EBITDA
# SpearmanrResult(correlation=-0.10938543983640502, pvalue=0.0505879274392347)
# ----
# Earnings Assets / Int Bear Liab
# SpearmanrResult(correlation=0.21998002070187672, pvalue=0.006833077833110406)
# ----
# Int Exp / Avg Int Bear Liab
# SpearmanrResult(correlation=0.3166978703487011, pvalue=0.0018716353782787)
# ----
# Interest Coverage Ratio
# SpearmanrResult(correlation=-0.4273767628203678, pvalue=1.8525554530986762e-13)
# ----
# TCE Ratio
# SpearmanrResult(correlation=-0.37871200266223204, pvalue=1.1439783216006485e-18)
#
# ##############################
#
# VAR = Interest Coverage Ratio
# ----
# Average Equity / Average Assets
# SpearmanrResult(correlation=0.3692904327117488, pvalue=9.09581888226256e-11)
# ----
# Common Eqty / Tot Assets
# SpearmanrResult(correlation=0.4088579619447129, pvalue=3.1066632121114724e-13)
# ----
# Debt/EBITDA
# SpearmanrResult(correlation=-0.560524407689745, pvalue=4.379545880476114e-22)
# ----
# EBITDA
# SpearmanrResult(correlation=0.5247129315572323, pvalue=3.952251515968688e-22)
# ----
# Earnings Assets / Int Bear Liab
# SpearmanrResult(correlation=nan, pvalue=nan)
# ----
# Int Exp / Avg Int Bear Liab
# SpearmanrResult(correlation=nan, pvalue=nan)
# ----
# Debt / Common Equity
# SpearmanrResult(correlation=-0.4273767628203678, pvalue=1.8525554530986762e-13)
# ----
# TCE Ratio
# SpearmanrResult(correlation=0.3495735586559396, pvalue=7.584932613350916e-10)
#
# ##############################
#
# VAR = TCE Ratio
# ----
# Average Equity / Average Assets
# SpearmanrResult(correlation=0.4085010030791034, pvalue=2.474524794654607e-22)
# ----
# Common Eqty / Tot Assets
# SpearmanrResult(correlation=0.43278585357343524, pvalue=1.6316315687661184e-25)
# ----
# Debt/EBITDA
# SpearmanrResult(correlation=-0.12409781163509274, pvalue=0.040098317504837715)
# ----
# EBITDA
# SpearmanrResult(correlation=-0.04081285367643418, pvalue=0.45186333050965355)
# ----
# Earnings Assets / Int Bear Liab
# SpearmanrResult(correlation=-0.3208650057178464, pvalue=5.898728815304911e-05)
# ----
# Int Exp / Avg Int Bear Liab
# SpearmanrResult(correlation=-0.39879631468513355, pvalue=0.00010842013137877283)
# ----
# Debt / Common Equity
# SpearmanrResult(correlation=-0.37871200266223204, pvalue=1.1439783216006485e-18)
# ----
# Interest Coverage Ratio
# SpearmanrResult(correlation=0.3495735586559396, pvalue=7.584932613350916e-10)

# %% [markdown]
# ## b. Kendall

# %%
print("TEST DE KENDALL")

for col1 in colonnes2 :
    print("\n##############################\n")
    print("VAR = " + col1)
    for col2 in colonnes2 : 
        
        if col1 != col2 :
    
            df_bis = var[[col1,col2]].dropna(how = 'any') 
        
            print("----")
            print(col2)
            print(stats.kendalltau(df_bis[col1],df_bis[col2]))
# Out:
# TEST DE KENDALL
#
# ##############################
#
# VAR = Average Equity / Average Assets
# ----
# Common Eqty / Tot Assets
# KendalltauResult(correlation=0.9403212122985111, pvalue=1.1919207215658565e-222)
# ----
# Debt/EBITDA
# KendalltauResult(correlation=-0.20483333333333337, pvalue=7.491209541395086e-07)
# ----
# EBITDA
# KendalltauResult(correlation=0.07619658576570798, pvalue=0.03931413550654255)
# ----
# Earnings Assets / Int Bear Liab
# KendalltauResult(correlation=-0.25429864253393664, pvalue=2.421074333756534e-05)
# ----
# Int Exp / Avg Int Bear Liab
# KendalltauResult(correlation=-0.156030089784033, pvalue=0.03627789696742105)
# ----
# Debt / Common Equity
# KendalltauResult(correlation=-0.5512536831200181, pvalue=1.762051038959367e-74)
# ----
# Interest Coverage Ratio
# KendalltauResult(correlation=0.26010686315173104, pvalue=8.213794812064693e-11)
# ----
# TCE Ratio
# KendalltauResult(correlation=0.3769471809553868, pvalue=7.687505794845605e-37)
#
# ##############################
#
# VAR = Common Eqty / Tot Assets
# ----
# Average Equity / Average Assets
# KendalltauResult(correlation=0.9403212122985111, pvalue=1.1919207215658565e-222)
# ----
# Debt/EBITDA
# KendalltauResult(correlation=-0.224772511204672, pvalue=4.711030196540184e-08)
# ----
# EBITDA
# KendalltauResult(correlation=0.0925793823401479, pvalue=0.011745589309618259)
# ----
# Earnings Assets / Int Bear Liab
# KendalltauResult(correlation=-0.2486576198379381, pvalue=3.108298510968896e-05)
# ----
# Int Exp / Avg Int Bear Liab
# KendalltauResult(correlation=-0.11817520019412762, pvalue=0.11278091989784593)
# ----
# Debt / Common Equity
# KendalltauResult(correlation=-0.5653325281066128, pvalue=2.3666264270056084e-79)
# ----
# Interest Coverage Ratio
# KendalltauResult(correlation=0.29111701622852804, pvalue=2.395459825669267e-13)
# ----
# TCE Ratio
# KendalltauResult(correlation=0.4006352814325888, pvalue=4.8939678476294596e-42)
#
# ##############################
#
# VAR = Debt/EBITDA
# ----
# Average Equity / Average Assets
# KendalltauResult(correlation=-0.20483333333333337, pvalue=7.491209541395086e-07)
# ----
# Common Eqty / Tot Assets
# KendalltauResult(correlation=-0.224772511204672, pvalue=4.711030196540184e-08)
# ----
# EBITDA
# KendalltauResult(correlation=-0.26959119923944047, pvalue=5.716731132424369e-11)
# ----
# Earnings Assets / Int Bear Liab
# KendalltauResult(correlation=0.28735632183908044, pvalue=0.19024347088451465)
# ----
# Int Exp / Avg Int Bear Liab
# KendalltauResult(correlation=0.6974789915966387, pvalue=0.0004698505631685479)
# ----
# Debt / Common Equity
# KendalltauResult(correlation=0.352986673012851, pvalue=5.4787840385754776e-17)
# ----
# Interest Coverage Ratio
# KendalltauResult(correlation=-0.4090834777490762, pvalue=2.6953344083985962e-21)
# ----
# TCE Ratio
# KendalltauResult(correlation=-0.10264837702023633, pvalue=0.012620006584191136)
#
# ##############################
#
# VAR = EBITDA
# ----
# Average Equity / Average Assets
# KendalltauResult(correlation=0.07619658576570798, pvalue=0.03931413550654255)
# ----
# Common Eqty / Tot Assets
# KendalltauResult(correlation=0.0925793823401479, pvalue=0.011745589309618259)
# ----
# Debt/EBITDA
# KendalltauResult(correlation=-0.26959119923944047, pvalue=5.716731132424369e-11)
# ----
# Earnings Assets / Int Bear Liab
# KendalltauResult(correlation=-0.052837573385518595, pvalue=0.6993252550647073)
# ----
# Int Exp / Avg Int Bear Liab
# KendalltauResult(correlation=0.4345549738219895, pvalue=0.01252411411962892)
# ----
# Debt / Common Equity
# KendalltauResult(correlation=-0.06410766902922674, pvalue=0.09205990019524436)
# ----
# Interest Coverage Ratio
# KendalltauResult(correlation=0.3717851380848439, pvalue=8.41678871037587e-21)
# ----
# TCE Ratio
# KendalltauResult(correlation=-0.018042627229230102, pvalue=0.623384605542207)
#
# ##############################
#
# VAR = Earnings Assets / Int Bear Liab
# ----
# Average Equity / Average Assets
# KendalltauResult(correlation=-0.25429864253393664, pvalue=2.421074333756534e-05)
# ----
# Common Eqty / Tot Assets
# KendalltauResult(correlation=-0.2486576198379381, pvalue=3.108298510968896e-05)
# ----
# Debt/EBITDA
# KendalltauResult(correlation=0.28735632183908044, pvalue=0.19024347088451465)
# ----
# EBITDA
# KendalltauResult(correlation=-0.052837573385518595, pvalue=0.6993252550647073)
# ----
# Int Exp / Avg Int Bear Liab
# KendalltauResult(correlation=-0.07812500000000001, pvalue=0.33616698179318627)
# ----
# Debt / Common Equity
# KendalltauResult(correlation=0.1411869612602794, pvalue=0.018547682405940857)
# ----
# Interest Coverage Ratio
# KendalltauResult(correlation=nan, pvalue=nan)
# ----
# TCE Ratio
# KendalltauResult(correlation=-0.24709557746753882, pvalue=3.484934926908422e-05)
#
# ##############################
#
# VAR = Int Exp / Avg Int Bear Liab
# ----
# Average Equity / Average Assets
# KendalltauResult(correlation=-0.156030089784033, pvalue=0.03627789696742105)
# ----
# Common Eqty / Tot Assets
# KendalltauResult(correlation=-0.11817520019412762, pvalue=0.11278091989784593)
# ----
# Debt/EBITDA
# KendalltauResult(correlation=0.6974789915966387, pvalue=0.0004698505631685479)
# ----
# EBITDA
# KendalltauResult(correlation=0.4345549738219895, pvalue=0.01252411411962892)
# ----
# Earnings Assets / Int Bear Liab
# KendalltauResult(correlation=-0.07812500000000001, pvalue=0.33616698179318627)
# ----
# Debt / Common Equity
# KendalltauResult(correlation=0.2028805562453439, pvalue=0.006854088937212849)
# ----
# Interest Coverage Ratio
# KendalltauResult(correlation=nan, pvalue=nan)
# ----
# TCE Ratio
# KendalltauResult(correlation=-0.28172163219675794, pvalue=0.0002861379616792627)
#
# ##############################
#
# VAR = Debt / Common Equity
# ----
# Average Equity / Average Assets
# KendalltauResult(correlation=-0.551253683120018, pvalue=1.762051038959367e-74)
# ----
# Common Eqty / Tot Assets
# KendalltauResult(correlation=-0.5653325281066128, pvalue=2.3666264270056084e-79)
# ----
# Debt/EBITDA
# KendalltauResult(correlation=0.352986673012851, pvalue=5.4787840385754776e-17)
# ----
# EBITDA
# KendalltauResult(correlation=-0.06410766902922674, pvalue=0.09205990019524436)
# ----
# Earnings Assets / Int Bear Liab
# KendalltauResult(correlation=0.1411869612602794, pvalue=0.018547682405940857)
# ----
# Int Exp / Avg Int Bear Liab
# KendalltauResult(correlation=0.2028805562453439, pvalue=0.006854088937212849)
# ----
# Interest Coverage Ratio
# KendalltauResult(correlation=-0.29747908502181825, pvalue=6.859343432493372e-13)
# ----
# TCE Ratio
# KendalltauResult(correlation=-0.2800027117615217, pvalue=1.7886325572018636e-20)
#
# ##############################
#
# VAR = Interest Coverage Ratio
# ----
# Average Equity / Average Assets
# KendalltauResult(correlation=0.26010686315173104, pvalue=8.213794812064693e-11)
# ----
# Common Eqty / Tot Assets
# KendalltauResult(correlation=0.29111701622852804, pvalue=2.395459825669267e-13)
# ----
# Debt/EBITDA
# KendalltauResult(correlation=-0.4090834777490762, pvalue=2.6953344083985962e-21)
# ----
# EBITDA
# KendalltauResult(correlation=0.3717851380848439, pvalue=8.41678871037587e-21)
# ----
# Earnings Assets / Int Bear Liab
# KendalltauResult(correlation=nan, pvalue=nan)
# ----
# Int Exp / Avg Int Bear Liab
# KendalltauResult(correlation=nan, pvalue=nan)
# ----
# Debt / Common Equity
# KendalltauResult(correlation=-0.29747908502181825, pvalue=6.859343432493372e-13)
# ----
# TCE Ratio
# KendalltauResult(correlation=0.2392047072221695, pvalue=1.7604101040520976e-09)
#
# ##############################
#
# VAR = TCE Ratio
# ----
# Average Equity / Average Assets
# KendalltauResult(correlation=0.3769471809553868, pvalue=7.687505794845605e-37)
# ----
# Common Eqty / Tot Assets
# KendalltauResult(correlation=0.4006352814325888, pvalue=4.8939678476294596e-42)
# ----
# Debt/EBITDA
# KendalltauResult(correlation=-0.10264837702023633, pvalue=0.012620006584191136)
# ----
# EBITDA
# KendalltauResult(correlation=-0.018042627229230102, pvalue=0.623384605542207)
# ----
# Earnings Assets / Int Bear Liab
# KendalltauResult(correlation=-0.24709557746753882, pvalue=3.484934926908422e-05)
# ----
# Int Exp / Avg Int Bear Liab
# KendalltauResult(correlation=-0.28172163219675794, pvalue=0.0002861379616792627)
# ----
# Debt / Common Equity
# KendalltauResult(correlation=-0.28000271176152164, pvalue=1.7886325572018636e-20)
# ----
# Interest Coverage Ratio
# KendalltauResult(correlation=0.2392047072221695, pvalue=1.7604101040520976e-09)

# %% [markdown]
# ## 2) en ne gardant que les variables avec peu de NaN

# %%
var2 = df[["Average Equity / Average Assets","Common Eqty / Tot Assets","Debt / Common Equity","TCE Ratio"]]

# %%
var2.isnull().sum(axis = 0)
# Out:
# Average Equity / Average Assets    37
# Common Eqty / Tot Assets           28
# Debt / Common Equity               52
# TCE Ratio                          36
# dtype: int64

# %%
corr_var2 = var2.corr(method='spearman')
sns.heatmap(corr_var2, xticklabels=corr_var2.columns, yticklabels=corr_var2.columns, vmin=0.00, vmax=1,cmap='coolwarm')
plt.title('Matrice de corrélation des variables')
# Out:
# Text(0.5, 1.0, 'Matrice de corrélation des variables')

# %%
colonnes3 = ["Average Equity / Average Assets","Common Eqty / Tot Assets","Debt / Common Equity"]

print("TEST DE SPEARMAN")

for col1 in colonnes3 :
    print("\n##############################\n")
    print("VAR = " + col1)
    for col2 in colonnes3 : 
        
        if col1 != col2 :
    
            df_bis = var2[[col1,col2]].dropna(how = 'any') 
        
            print("----")
            print(col2)
            print(stats.spearmanr(df_bis[col1],df_bis[col2]))
# Out:
# TEST DE SPEARMAN
#
# ##############################
#
# VAR = Average Equity / Average Assets
# ----
# Common Eqty / Tot Assets
# SpearmanrResult(correlation=0.9878115933767302, pvalue=0.0)
# ----
# Debt / Common Equity
# SpearmanrResult(correlation=-0.6891318405090693, pvalue=7.5952611177317065e-78)
#
# ##############################
#
# VAR = Common Eqty / Tot Assets
# ----
# Average Equity / Average Assets
# SpearmanrResult(correlation=0.9878115933767302, pvalue=0.0)
# ----
# Debt / Common Equity
# SpearmanrResult(correlation=-0.6880372119803523, pvalue=1.7420150310955214e-78)
#
# ##############################
#
# VAR = Debt / Common Equity
# ----
# Average Equity / Average Assets
# SpearmanrResult(correlation=-0.6891318405090693, pvalue=7.5952611177317065e-78)
# ----
# Common Eqty / Tot Assets
# SpearmanrResult(correlation=-0.6880372119803523, pvalue=1.7420150310955214e-78)

# %%
print("TEST DE KENDALL")

for col1 in colonnes3 :
    print("\n##############################\n")
    print("VAR = " + col1)
    for col2 in colonnes3 : 
        
        if col1 != col2 :
    
            df_bis = var2[[col1,col2]].dropna(how = 'any') 
        
            print("----")
            print(col2)
            print(stats.kendalltau(df_bis[col1],df_bis[col2]))
# Out:
# TEST DE KENDALL
#
# ##############################
#
# VAR = Average Equity / Average Assets
# ----
# Common Eqty / Tot Assets
# KendalltauResult(correlation=0.9364807737404851, pvalue=3.0302007030672375e-237)
# ----
# Debt / Common Equity
# KendalltauResult(correlation=-0.5585870832214281, pvalue=2.8766608970532025e-82)
#
# ##############################
#
# VAR = Common Eqty / Tot Assets
# ----
# Average Equity / Average Assets
# KendalltauResult(correlation=0.9364807737404851, pvalue=3.0302007030672375e-237)
# ----
# Debt / Common Equity
# KendalltauResult(correlation=-0.5680775533463505, pvalue=3.783770773858007e-86)
#
# ##############################
#
# VAR = Debt / Common Equity
# ----
# Average Equity / Average Assets
# KendalltauResult(correlation=-0.5585870832214282, pvalue=2.8766608970532025e-82)
# ----
# Common Eqty / Tot Assets
# KendalltauResult(correlation=-0.5680775533463505, pvalue=3.783770773858007e-86)

# %%
#PEARSON

print("TEST DE PEARSON")

for col1 in colonnes3 :
    print("\n##############################\n")
    print("VAR = " + col1)
    for col2 in colonnes3 : 
        
        if col1 != col2 :
    
            df_bis = var2[[col1,col2]].dropna(how = 'any') 
        
            print("----")
            print(col2)
            print(stats.pearsonr(df_bis[col1],df_bis[col2]))
# Out:
# TEST DE PEARSON
#
# ##############################
#
# VAR = Average Equity / Average Assets
# ----
# Common Eqty / Tot Assets
# (0.9870870450730153, 0.0)
# ----
# Debt / Common Equity
# (-0.13059673323875504, 0.0022725574946073092)
#
# ##############################
#
# VAR = Common Eqty / Tot Assets
# ----
# Average Equity / Average Assets
# (0.9870870450730153, 0.0)
# ----
# Debt / Common Equity
# (-0.1252560524354834, 0.0032283612348077287)
#
# ##############################
#
# VAR = Debt / Common Equity
# ----
# Average Equity / Average Assets
# (-0.13059673323875504, 0.0022725574946073092)
# ----
# Common Eqty / Tot Assets
# (-0.1252560524354834, 0.0032283612348077287)

# %% [markdown]
# On retrouve le doublon entre Common Eqty / Tot Aassets et Average Equity / Average Assets.

# %% [markdown]
# ### CONCLUSION SUR LES VARIABLES QUANTI
#
# Variables d'intérêt : Average Equity / Average Assets, Common Eqty / Tot Assets, Int Exp / Avg Int Bear Liab (0%), Debt/EBITDA, EBITDA, Earnings Assets / Int Bear Liab, Debt / Common Equity
#
# **Variables d'intérêt moins les doublons : Common Eqty / Tot Assets, Debt/EBITDA, EBITDA, Earnings Assets / Int Bear Liab, Debt / Common Equity.**
#
# Variables d'intéret moins les doublons moins ceux avec bcp de valeurs manquantes : Common Eqty / Tot Assets, Debt / Common Equity

# %% [markdown]
# # Autres fonctions
#
# *inutile*

# %%
#renvoyer tous les duos avec une corrélation au dessus d'un certain seuil 

def high_corr(corr_df, seuil) : 
    
    duos = []
    
    col = np.array(corr_df.columns) 
    corr = corr_df.to_numpy()
    corr = np.abs(corr)
    
    for i in range(0,len(corr)) : 
        for j in range(0,i) : 
            
            if corr[i][j] > seuil : 
                
                duos.append(col[i] + " AND " + col[j]) 
                
    return duos

# %%
def low_corr(corr_df, seuil) : 
    
    duos = []
    
    col = np.array(corr_df.columns) 
    corr = corr_df.to_numpy()
    corr = np.abs(corr)
    
    for i in range(0,len(corr)) : 
        for j in range(0,i) : 
            
            if corr[i][j] <= seuil : 
                
                duos.append(col[i] + " AND " + col[j]) 
                
    return duos

# %% [markdown]
# # II. VARIABLES QUALITATIVES

# %% [markdown]
# # Etude des secteurs
#
# On récupère de Bloom 4 variables relatives aux secteurs des bonds, lesquels sont inclus les uns dans les autres (toutes les observations d'une même modalité de la variable n a la même valeur pour la variable n-1). La précision augmente avec le numéro de la variable. **Nous cherchons l'échelle la plus pertinente (doit être ni trop large ni trop précise)**.
#
# Pour cela, nous allons réaliser des tests d'indépendance entre la variable d'intérêt *PD_1y* et chaque variable sectorielle. Nous garderons la variable sectorielle la plus corrélée à la variable d'intérêt.
#
# **Identification de plusieurs tests pertinents :** Nous cherchons donc un test d'indépendance entre une variable qualitative et une variable quantitative (à plus de 2 groupes).
#
# $-$ test ANOVA (paramétrique, suppose que les résidus suivent une loi normale)
#
# $-$ test de Kruskall-Wallis (non paramétrique)

# %%
quali = df[["PD_1y","BCLASS Level 1","BCLASS Level 2","BCLASS Level 3","BCLASS Level 4"]]

# %%
quali
# Out:
#         PD_1y BCLASS Level 1          BCLASS Level 2         BCLASS Level 3  \
# 0    0.053266      Corporate  Financial Institutions                Banking
# 1    0.068537      Corporate              Industrial      Consumer Cyclical
# 2    0.119209      Corporate              Industrial      Consumer Cyclical
# 3    0.030968      Corporate              Industrial         Basic Industry
# 4    0.016911      Corporate              Industrial         Basic Industry
# ..        ...            ...                     ...                    ...
# 598  0.018921      Corporate  Financial Institutions                Banking
# 599  0.008796      Corporate  Financial Institutions                Banking
# 600  0.035679      Corporate  Financial Institutions                Banking
# 601  0.020427      Corporate  Financial Institutions                Banking
# 602  0.194359      Corporate              Industrial  Consumer Non-Cyclical
#
#         BCLASS Level 4
# 0              Banking
# 1            Retailers
# 2            Retailers
# 3    Metals and Mining
# 4    Metals and Mining
# ..                 ...
# 598            Banking
# 599            Banking
# 600            Banking
# 601            Banking
# 602         Healthcare
#
# [603 rows x 5 columns]

# %%
quali_2 = quali.dropna(how = 'any')
quali_2
#aucune valeur manquante sur ce dataset, tant mieux
# Out:
#         PD_1y BCLASS Level 1          BCLASS Level 2         BCLASS Level 3  \
# 0    0.053266      Corporate  Financial Institutions                Banking
# 1    0.068537      Corporate              Industrial      Consumer Cyclical
# 2    0.119209      Corporate              Industrial      Consumer Cyclical
# 3    0.030968      Corporate              Industrial         Basic Industry
# 4    0.016911      Corporate              Industrial         Basic Industry
# ..        ...            ...                     ...                    ...
# 598  0.018921      Corporate  Financial Institutions                Banking
# 599  0.008796      Corporate  Financial Institutions                Banking
# 600  0.035679      Corporate  Financial Institutions                Banking
# 601  0.020427      Corporate  Financial Institutions                Banking
# 602  0.194359      Corporate              Industrial  Consumer Non-Cyclical
#
#         BCLASS Level 4
# 0              Banking
# 1            Retailers
# 2            Retailers
# 3    Metals and Mining
# 4    Metals and Mining
# ..                 ...
# 598            Banking
# 599            Banking
# 600            Banking
# 601            Banking
# 602         Healthcare
#
# [593 rows x 5 columns]

# %%
quali_2.rename(columns={'BCLASS Level 1':'Level1'}, inplace=True)
quali_2.rename(columns={'BCLASS Level 2':'Level2'}, inplace=True)
quali_2.rename(columns={'BCLASS Level 3':'Level3'}, inplace=True)
quali_2.rename(columns={'BCLASS Level 4':'Level4'}, inplace=True)
# Out:
# C:\Users\mathilde.binet\Anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# ## 1. Etudes graphiques

# %%
print("Level 1, il y a", len(quali_2['Level1'].unique()), " modalités.")
print("Level 2, il y a", len(quali_2['Level2'].unique()), " modalités.")
print("Level 3, il y a", len(quali_2['Level3'].unique()), " modalités.")
print("Level 4, il y a", len(quali_2['Level4'].unique()), " modalités.")
# Out:
# Level 1, il y a 3  modalités.
# Level 2, il y a 7  modalités.
# Level 3, il y a 22  modalités.
# Level 4, il y a 43  modalités.

# %%
print("\n########### LEVEL 1 ###########")
print(quali_2['Level1'].value_counts())
print("\n########### LEVEL 2 ###########")
print(quali_2['Level2'].value_counts())
print("\n########### LEVEL 3 ###########")
print(quali_2['Level3'].value_counts())
print("\n########### LEVEL 4 ###########")
print(quali_2['Level4'].value_counts())
# Out:
# ########### LEVEL 1 ###########
# Corporate             554
# Government-Related     28
# Securitized            11
# Name: Level1, dtype: int64
#
# ########### LEVEL 2 ###########
# Financial Institutions    282
# Industrial                260
# Utility                    12
# Local Authority            12
# Agency                     12
# Covered                    11
# Supranational               4
# Name: Level2, dtype: int64
#
# ########### LEVEL 3 ###########
# Banking                              155
# Other Financial                       68
# Consumer Non-Cyclical                 67
# Transportation                        48
# Insurance                             45
# Capital Goods                         33
# Communications                        27
# Technology                            27
# Consumer Cyclical                     26
# Basic Industry                        24
# Local Authority                       12
# Government Owned. No Guarantee        12
# Mortgage Assets                       11
# REITs                                  8
# Other Industrial                       7
# Electric                               6
# Brokerage Assetmanagers Exchanges      5
# Supranational                          4
# Natural Gas                            4
# Other Utility                          2
# Finance Companies                      1
# Energy                                 1
# Name: Level3, dtype: int64
#
# ########### LEVEL 4 ###########
# Banking                              155
# Other Financial                       68
# Transportation Services               41
# Life                                  39
# Technology                            27
# Pharmaceuticals                       24
# Food and Beverage                     22
# Chemicals                             18
# Wireless                              13
# Diversified Manufacturing             13
# Local Authority                       12
# Cable Satellite                       12
# Government Owned. No Guarantee        12
# Tobacco                               12
# Mortgage Non Pfandbriefe              11
# Aerospace/Defense                      9
# Retailers                              9
# Other Industrial                       7
# Healthcare                             7
# Automotive                             7
# Airlines                               7
# Electric                               6
# Packaging                              6
# Brokerage Assetmanagers Exchanges      5
# P&C                                    5
# Consumer Cyc Services                  5
# Other REITs                            4
# Lodging                                4
# Office REITs                           4
# Metals and Mining                      4
# Supranational                          4
# Natural Gas                            4
# Construction Machinery                 2
# Environmental                          2
# Supermarkets                           2
# Paper                                  2
# Other Utility                          2
# Media Entertainment                    2
# Health Insurance                       1
# Finance Companies                      1
# Building Materials                     1
# Independent                            1
# Leisure                                1
# Name: Level4, dtype: int64

# %% [markdown]
# En diminuant l'échelle (augmenter le level), certaines classes sont de moins en moins peuplées (une observation). Pas très fiable, il faudrait faire avec bien plus de données.

# %%
#LEVEL 1
modalites = quali_2['Level1'].unique()

groupes = []
for m in modalites:
    groupes.append(quali_2[quali_2['Level1']==m]["PD_1y"])

# Propriétés graphiques (pas très importantes)    
medianprops = {'color':"black"}
meanprops = {'marker':'o', 'markeredgecolor':'black',
            'markerfacecolor':'firebrick'}
    
plt.boxplot(groupes, labels=modalites, showfliers=False, medianprops=medianprops, 
            vert=False, patch_artist=True, showmeans=True, meanprops=meanprops)
plt.show()

# %%
#LEVEL 2
modalites = quali_2['Level2'].unique()

groupes = []
for m in modalites:
    groupes.append(quali_2[quali_2['Level2']==m]["PD_1y"])

# Propriétés graphiques (pas très importantes)    
medianprops = {'color':"black"}
meanprops = {'marker':'o', 'markeredgecolor':'black',
            'markerfacecolor':'firebrick'}
    
plt.boxplot(groupes, labels=modalites, showfliers=False, medianprops=medianprops, 
            vert=False, patch_artist=True, showmeans=True, meanprops=meanprops)
plt.show()

# %%
#LEVEL 3
modalites = quali_2['Level3'].unique()

groupes = []
for m in modalites:
    groupes.append(quali_2[quali_2['Level3']==m]["PD_1y"])

# Propriétés graphiques (pas très importantes)    
medianprops = {'color':"black"}
meanprops = {'marker':'o', 'markeredgecolor':'black',
            'markerfacecolor':'firebrick'}
    
plt.boxplot(groupes, labels=modalites, showfliers=False, medianprops=medianprops, 
            vert=False, patch_artist=True, showmeans=True, meanprops=meanprops)
plt.show()

# %%
#LEVEL 4
modalites = quali_2['Level4'].unique()

groupes = []
for m in modalites:
    groupes.append(quali_2[quali_2['Level4']==m]["PD_1y"])

# Propriétés graphiques (pas très importantes)    
medianprops = {'color':"black"}
meanprops = {'marker':'o', 'markeredgecolor':'black',
            'markerfacecolor':'firebrick'}
    
plt.boxplot(groupes, labels=modalites, showfliers=False, medianprops=medianprops, 
            vert=False, patch_artist=True, showmeans=True, meanprops=meanprops)
plt.show()

# %% [markdown]
# ## 2. ANOVA / Test F
#
# ANOVA (ou analyse de la variance) permet de déterminer si les moyennes des groupes sont égales. ANOVA utilise des tests F (Fischer) pour tester statistiquement l'égalité des moyennes. La **statistique F** est un ratio de deux écart-types : variation entre les moyennes d'échantillonage sur variation à l'intérieur des échantillons.
#
# **Hypothèse** $H_0$ *:* $M_1 = M_2 = \ ... \ = M_k$ *(indépendance). VS* $H_1$ *:*  il existe au moins un couple (i,j) tel que $M_i \ne M_j$ *(non indépendance)*
#
# **p-value :** Si $Pr_{obs} < Pr_{seuil}$, on rejette l'hypothèse $H_0$ d'indépendance.
#
#
# --------
#
# **Limites :**
# Il y a 3 hypothèses à vérifier : les résidus sont indépendants, les résidus suivent une loi Normale de moyenne 0 et de variance = variance résiduelle, les résidus sont homogènes.
#
# --------

# %%
import statsmodels.formula.api
import statsmodels.api

# %%
fit1 = statsmodels.formula.api.ols('PD_1y ~ Level1', data = quali_2).fit()

#table = statsmodels.api.stats.anova_lm(fit,robust = 'hc3')
table1 = statsmodels.api.stats.anova_lm(fit1)
table1
# Out:
#              df    sum_sq   mean_sq         F   PR(>F)
# Level1      2.0  0.018841  0.009421  1.839102  0.15987
# Residual  590.0  3.022225  0.005122       NaN      NaN

# %%
fit2 = statsmodels.formula.api.ols('PD_1y ~ Level2', data = quali_2).fit()

#table = statsmodels.api.stats.anova_lm(fit,robust = 'hc3') #robuste à l'hétéroscédasticité 
table2 = statsmodels.api.stats.anova_lm(fit2)
table2
# Out:
#              df    sum_sq   mean_sq         F   PR(>F)
# Level2      6.0  0.051938  0.008656  1.697028  0.11932
# Residual  586.0  2.989128  0.005101       NaN      NaN

# %%
fit3 = statsmodels.formula.api.ols('PD_1y ~ Level3', data = quali_2).fit()

table3 = statsmodels.api.stats.anova_lm(fit3,robust = 'hc3')
#table3 = statsmodels.api.stats.anova_lm(fit3)
table3
# Out:
#              df    sum_sq   mean_sq         F        PR(>F)
# Level3     21.0  0.345325  0.016444  3.483106  3.572487e-07
# Residual  571.0  2.695741  0.004721       NaN           NaN

# %%
fit4 = statsmodels.formula.api.ols('PD_1y ~ Level4', data = quali_2).fit()

table4 = statsmodels.api.stats.anova_lm(fit4,robust = 'hc3')
#table4 = statsmodels.api.stats.anova_lm(fit4)
table4
# Out:
#              df    sum_sq   mean_sq         F        PR(>F)
# Level4     42.0  0.968679  0.023064  6.120996  1.140532e-25
# Residual  550.0  2.072388  0.003768       NaN           NaN

# %% [markdown]
# Les secteurs pris aux échelles 3 et 4 sont statistiquement significatifs.

# %% [markdown]
# Le principe du test de Kruskall-Wallis est identique, avec des hypothèses moins restrictives.
#
# ## 3. Test de Kruskall-Wallis
#
# Il s'agit d'un test non paramétrique à utiliser lorsque l'on est en présence de k échantillons indépendants, afin de déterminer si les échantillons proviennent d'une même population ou si au moins un échantillon provient d'une population différente des autres.
#
#
# $k$ échantillons = $k$ groupes formés par la modalité de la variable. On compare les distributions des groupes pour voir s'ils sont distribués pareillement.
#
# **Hypothèse** $H_0$ *:* $M_1 = M_2 = \ ... \ = M_k$ *(indépendance). VS* $H_1$ *:*  il existe au moins un couple (i,j) tel que $M_i \ne M_j$ *(non indépendance)*
#
# **p-value :** Si $\alpha_{obs} < \alpha_{seuil}$, on rejette l'hypothèse $H_0$ d'indépendance.

# %%
from scipy import stats

# %%
#LEVEL 1
arr = []
for sector in quali_2['Level1'].unique() : 
    arr.append(quali_2[quali_2["Level1"] == sector]["PD_1y"].values)

stats.mstats.kruskalwallis(arr[0],arr[1],arr[2])
# Out:
# KruskalResult(statistic=42.349630422483735, pvalue=6.366409918910258e-10)

# %%
#LEVEL 2
arr = []
for sector in quali_2['Level2'].unique() :     
    arr.append(quali_2[quali_2["Level2"] == sector]["PD_1y"].values)

stats.mstats.kruskalwallis(arr[0],arr[1],arr[2],arr[3],arr[4],arr[5],arr[6])
# Out:
# KruskalResult(statistic=49.73843801059403, pvalue=5.304207818518009e-09)

# %%
#LEVEL 3
arr = []
for sector in quali_2['Level3'].unique() :     
    arr.append(quali_2[quali_2["Level3"] == sector]["PD_1y"].values)

stats.mstats.kruskalwallis(arr[0],arr[1],arr[2],arr[3],arr[4],arr[5],arr[6],arr[7],arr[8],arr[9],arr[10],arr[11],arr[12],arr[13],arr[14],arr[15],arr[16],arr[17],arr[18],arr[19],arr[20],arr[21])
# Out:
# KruskalResult(statistic=119.99223472884972, pvalue=7.164257798080409e-16)

# %%
#LEVEL 4
arr = []
for sector in quali_2['Level4'].unique() :     
    arr.append(quali_2[quali_2["Level4"] == sector]["PD_1y"].values)

stats.mstats.kruskalwallis(arr[0],arr[1],arr[2],arr[3],arr[4],arr[5],arr[6],arr[7],arr[8],arr[9],arr[10],arr[11],arr[12],arr[13],arr[14],arr[15],arr[16],arr[17],arr[18],arr[19],arr[20],arr[21],arr[22],arr[23],arr[24],arr[25],arr[26],arr[27],arr[28],arr[29],arr[30],arr[31],arr[32],arr[33],arr[34],arr[35],arr[36],arr[37],arr[38],arr[39],arr[40],arr[41],arr[42])
# Out:
# KruskalResult(statistic=207.72557724506382, pvalue=8.467029408005822e-24)

# %% [markdown]
# Les p-values du test aux différents niveaux sont très faibles. Le secteur a a priori un effet significatif sur la PD des entreprises.
#
# Aux vues des résultats des 2 tests, choix à faire entre les échelles 3 et 4.
#
#
# 4 est a priori plus significatif que 3, mais j'ai peur qu'il y ait trop de modalités et pas assez d'observations pour chaque modalité. Il faudrait retester avec bien plus de valeurs mais **3 me semble un bon compromis**.

# %% [markdown]
# # Conclusion :
#
# Variables d'intérêt : Average Equity / Average Assets, Common Eqty / Tot Assets, Int Exp / Avg Int Bear Liab (0%), Debt/EBITDA, EBITDA, Earnings Assets / Int Bear Liab, Debt / Common Equity, BCLASS Level 3
#
# **Variables d'intérêt moins les doublons : Common Eqty / Tot Assets, Debt/EBITDA, EBITDA, Earnings Assets / Int Bear Liab, Debt / Common Equity, BCLASS Level 3, Interest Coverage Ratio, TCE Ratio, Risk-Based Cap Ratio**
#
# Variables d'intéret moins les doublons moins ceux avec bcp de valeurs manquantes : Common Eqty / Tot Assets, Debt / Common Equity, BCLASS Level 3, TCE Ratio
