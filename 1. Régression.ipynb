# %% [markdown]
# # Régression de la probabilité de défaut

# %% [markdown]
# Premier notebook : **prédiction de la probabilité de défaut**. On parle de **régression** lorsqu'on explique une variable quantitative $Y$ avec des variables explicatives $X$. La probabilité de défaut est ici une variable quantitative continue, comprise entre 0 et 1. (en opposition avec le notebook 2, où l'on fait de la classification des probabilités de défaut).

# %% [markdown]
# # 1. Préparation des données

# %% [markdown]
# *Chargement des modules*

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import randn
import tensorflow as tf

from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv1D, Conv2D
from tensorflow.keras.optimizers import SGD,Adam,Nadam,Adadelta
from tensorflow import keras

from sklearn import preprocessing, model_selection
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## a. Chargement des données

# %%
df = pd.read_csv('market_data_pd.csv',sep=',')
df.shape
# Out:
# (48836, 24)

# %%
df.sort_values('Error %', ascending=False).head()
# Out:
#        Unnamed: 0 Reference Security  Bid Price  Ask Price  Mid Price     Cpn  \
# 5909         5909      ZS424035 Corp      0.010      0.750     0.3800  1.5000
# 1456         1456      AN346569 Corp      0.125      0.700     0.4125  3.8750
# 827           827      AL458635 Corp      0.250      1.750     1.0000  6.2500
# 44900       44900      QJ879163 Corp      0.407      1.481     0.9440  9.8776
# 44899       44899      QJ879163 Corp      0.396      1.499     0.9475  9.8776
#
#          Maturity  Common Eqty / Tot Assets  Debt / Common Equity  TCE Ratio  \
# 5909   04/26/2024                -147.17300                   NaN -149.82800
# 1456   10/25/2022                  12.72580               177.366  -23.21850
# 827    06/15/2022                       NaN                   NaN        NaN
# 44900  12/01/2025                   5.74708               467.713    4.97044
# 44899  12/01/2025                   5.74708               467.713    4.97044
#
#        ...       Amt Out  Total Assets     BCLASS Level 3  Guarantee Type  \
# 5909   ...  1.186770e+09       3359.72   Other Industrial        Multiple
# 1456   ...  4.000000e+08       1808.09           Electric        Multiple
# 827    ...  7.500000e+08           NaN  Consumer Cyclical            N.A.
# 44900  ...  2.000000e+08    1002610.00            Banking            N.A.
# 44899  ...  2.000000e+08    1002610.00            Banking            N.A.
#
#               Guarantor Type   Collat Type PD_1y    reprice maturity_years  \
# 5909            Subsidiaries    SR SECURED   1.0  40.007513       2.709589
# 1456   Parent & Subsidiaries    SR SECURED   1.0  40.007513       1.205479
# 827                     N.A.  SR UNSECURED   1.0  42.507983       0.843836
# 44900                   N.A.  SUBORDINATED   1.0  40.007513       4.309589
# 44899                   N.A.  SUBORDINATED   1.0  40.007513       4.309589
#
#             Error %
# 5909   10428.292944
# 1456    9598.791076
# 827     4150.798276
# 44900   4138.084024
# 44899   4122.428832
#
# [5 rows x 24 columns]

# %%
def count_nan(df):
    for col_name in df.columns:
        n_nan = df[col_name].isna().sum()
        if n_nan > 0:
            print("Colomn : ", col_name)  
            print("NaN : {}/{}".format(n_nan,len(df[col_name])))
            print("===============================================")
            
#count_nan(df)

# %%
df = df[df.PD_1y>0.0]
df = df[df.PD_1y!=1.0]

df.columns
# Out:
# Index(['Unnamed: 0', 'Reference Security', 'Bid Price', 'Ask Price',
#        'Mid Price', 'Cpn', 'Maturity', 'Common Eqty / Tot Assets',
#        'Debt / Common Equity', 'TCE Ratio', 'Tot Debt / Tot Capital',
#        'Tot Cap (Local Crncy)', 'Is Covered', 'Is Convertible', 'Amt Out',
#        'Total Assets', 'BCLASS Level 3', 'Guarantee Type', 'Guarantor Type',
#        'Collat Type', 'PD_1y', 'reprice', 'maturity_years', 'Error %'],
#       dtype='object')

# %%
#Sélectionne seulement les variables de notre modèle 

df1 = df[['Common Eqty / Tot Assets','TCE Ratio','Tot Debt / Tot Capital','Tot Cap (Local Crncy)','Amt Out','Is Covered','Is Convertible','BCLASS Level 3', 'Guarantee Type','Total Assets', 'Guarantor Type', 'Collat Type','Debt / Common Equity','PD_1y']]
df1 = df1[df1['Debt / Common Equity']<2500]
df1 = df1[df1['TCE Ratio']>-100]
#df1.replace(np.nan, 0.0,inplace=True)
df1.dropna(inplace=True)

# %%
df1.shape
# Out:
# (36781, 14)

# %%
df1
# Out:
#        Common Eqty / Tot Assets  TCE Ratio  Tot Debt / Tot Capital  \
# 2                      5.655220   5.412310                 84.0491
# 3                     35.988000   2.221370                 53.9594
# 4                      5.713810   5.246640                 85.8881
# 5                     23.508300  19.213600                 63.4410
# 6                      4.547990   3.851140                 85.6341
# ...                         ...        ...                     ...
# 48817                 12.191700  12.189800                 86.0465
# 48825                 12.179400  12.154600                 66.5225
# 48826                  4.907200   4.893530                 94.7512
# 48828                  5.819530   5.789880                 93.5507
# 48834                  0.000126   0.000126                  0.0000
#
#        Tot Cap (Local Crncy)       Amt Out  Is Covered  Is Convertible  \
# 2                1077950.000  1.000000e+09       False           False
# 3                 125576.000  6.060820e+08       False           False
# 4                 333470.000  1.500000e+09       False           False
# 5                 151388.000  6.000000e+08       False           False
# 6                 226753.000  1.100000e+09       False           False
# ...                      ...           ...         ...             ...
# 48817             136118.000  3.860000e+07       False           False
# 48825               2032.590  5.000000e+06        True           False
# 48826              89085.000  5.265000e+05       False           False
# 48828             493031.000  3.200000e+07       False           False
# 48834                  0.031  7.500000e+07       False           False
#
#               BCLASS Level 3 Guarantee Type  Total Assets  \
# 2                    Banking           N.A.    3040430.00
# 3             Communications           N.A.     155063.00
# 4                    Banking           N.A.     809688.00
# 5          Consumer Cyclical         Single     235381.00
# 6                    Banking           N.A.     627244.00
# ...                      ...            ...           ...
# 48817        Local Authority         Single     155787.00
# 48825        Mortgage Assets           N.A.       5586.66
# 48826  Government Guaranteed         Single      95286.50
# 48828  Government Guaranteed         Single     546384.00
# 48834        Other Financial           N.A.      24558.60
#
#                       Guarantor Type       Collat Type  Debt / Common Equity  \
# 2                               N.A.      SR UNSECURED               526.924
# 3                               N.A.      SR UNSECURED               121.425
# 4                               N.A.      SR UNSECURED               619.080
# 5                             Parent    COMPANY GUARNT               173.568
# 6                               N.A.      SR UNSECURED               680.681
# ...                              ...               ...                   ...
# 48817               Local Government  LOCAL GOVT GUARN               616.668
# 48825                           N.A.       PFANDBRIEFE               198.720
# 48826  National/Sovereign Government   GOVT GUARANTEED              1805.190
# 48828  National/Sovereign Government   GOVT GUARANTEED              1450.560
# 48834                           N.A.           SECURED                 0.000
#
#           PD_1y
# 2      0.012445
# 3      0.020474
# 4      0.001146
# 5      0.001179
# 6      0.002144
# ...         ...
# 48817  0.015262
# 48825  0.023219
# 48826  0.003846
# 48828  0.013188
# 48834  0.019929
#
# [36781 rows x 14 columns]

# %%
#df1 = df1.drop_duplicates(subset=df1.columns.difference(['PD_1y']))
df1.shape
# Out:
# (36781, 14)

# %%
df1 = df1.drop_duplicates()
df1.shape
# Out:
# (36096, 14)

# %% [markdown]
# ## b. Traitement des données

# %% [markdown]
# Nous commencerons par séparer les données non étiquietées des étiquettes, les étiquettes se trouvent dans l'array `y_full` et le reste des données dans `X_full`

# %%
X_full = np.array(df1.drop(columns=['PD_1y']))
y_full = np.array(df1['PD_1y'])

# %% [markdown]
# La prochaine étape consiste à séparer les features continues des features discrètes, cela sera utile car leurs traitements seront différent

# %%
features = list(df1.drop(columns=['PD_1y']).columns)

discrete_features = ['BCLASS Level 3','Guarantee Type','Guarantor Type','Collat Type','Is Covered','Is Convertible']
continuous_features = [s for s in features if not s in discrete_features]


continuous_features_idx = [features.index(feat_name) for feat_name in continuous_features]
discrete_features_idx = [features.index(feat_name) for feat_name in discrete_features]

# %% [markdown]
# ## i. Statistiques descriptives

# %%
fig = plt.figure(figsize=(14,10))

# Histograms for continuous features
for (plot_idx, feat_idx) in enumerate(continuous_features_idx):

    # create a subplot in the (plot_idx+1) position of a 2x2 grid
    ax = fig.add_subplot(8, 2, (plot_idx+1))
    # plot the histogram of feat_idx
    h = ax.hist(X_full[:, feat_idx], bins=30, edgecolor='black')
    # use the name of the feature as a title for each histogram
    ax.set_title(features[feat_idx])
    #plt.xlim(0,0.001)
# espacement entre les subplots
fig.tight_layout(pad=0.1)
#fig.savefig('continuous_distrib.png')

# %%
# Bar plots for discrete features
fig = plt.figure(figsize=(20, 36))

for (plot_idx, feat_idx) in enumerate(discrete_features_idx):
    # create a subplot in the (plot_idx+1) position of a 1x3 grid
    ax = fig.add_subplot(7, 1, (plot_idx+1))

    feature_values = np.unique(X_full[:, feat_idx])
    frequencies = [(float(len(np.where(X_full[:, feat_idx]==value)[0]))/X_full.shape[0]) \
                   for value in feature_values]
    
    b = ax.bar(range(len(feature_values)), frequencies, width=0.8, 
               tick_label=list([n for n in feature_values]))
    
    
    # use the name of the feature as a title for each histogram
    ax.set_title(features[feat_idx])
    
fig.tight_layout(pad=0.15)
fig.savefig('discrete_distrib.png')

# %% [markdown]
# ## ii. Traitement des données

# %% [markdown]
# Les variables explicatives doivent être recodées de la façon suivante :
#
# $-$ les variables quantitatives standarisées (moyenne nulle, écart-type de 1).
#
# $-$ à partir des variables qualitatives (à plusieurs modalités), on crée une variable binaire par modalités.
#
# La transformation des variables quantitatives doit être fait en s'appuyant sur la base de train (définie ensuite), puis appliquée sur la base de test. Pour les variables qualitatives, comme nous créeons de nouvelles variables, il nous faut connaître toutes les modalités prises par les variables (y compris celles prises uniquement dans la base de test).

# %%
## A FAIRE COMME CELA :
"""
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(handle_unknown='ignore')
enc.fit(X_train_submit)

X_train_submit = enc.transform(X_train_submit)
X_test_submit = enc.transform(X_test_submit)

"""



class Pipeline:
    def __init__(self, X_train, X_full = None):
        """
        Se fit sur le jeu de TRAIN, une seule fois
        """
        self.ohe = preprocessing.OneHotEncoder(categories='auto',sparse=False).fit(X_full[:,discrete_features_idx])
        self.std_scaler = preprocessing.StandardScaler().fit(X_train[:,continuous_features_idx])
        print(self.ohe.categories_)
        
    def traitement(self,X):
        """
        Permet de traiter n'importe quel vecteur X ensuite
        """
    
        X_continuous_scaled = self.std_scaler.transform(X[:,continuous_features_idx])
        X_discrete_encoded = self.ohe.transform(X[:,discrete_features_idx])
        print('moyenne = {}'.format(np.mean(X_continuous_scaled)))
        
        X_processed = np.hstack((X_discrete_encoded, X_continuous_scaled))
    
        return X_processed

# %%
X_train, X_test_, y_train, y_test = model_selection.train_test_split(X_full, y_full, test_size=0.1,
                                                                    #stratify=y_full, # stratification
                                                                    random_state=92)

pipe = Pipeline(X_train,X_full)
X_train = pipe.traitement(X_train)
X_test  = pipe.traitement(X_test_)
# Out:
# [array(['Banking', 'Basic Industry', 'Brokerage Assetmanagers Exchanges',
#        'Capital Goods', 'Communications', 'Consumer Cyclical',
#        'Consumer Non-Cyclical', 'Electric', 'Energy', 'Finance Companies',
#        'Government Guaranteed', 'Government Owned. No Guarantee',
#        'Government Sponsored', 'Hybrid', 'Insurance', 'Local Authority',
#        'Mortgage Assets', 'Natural Gas', 'Other Financial',
#        'Other Industrial', 'Other Utility', 'Public Sector Loans',
#        'REITs', 'Supranational', 'Technology', 'Transportation',
#        'Whole Business'], dtype=object), array(['Cross Guarantee', 'Multiple', 'N.A.', 'Single'], dtype=object), array(['Bank', 'Company', 'Domestic Restricted Subsidiar',
#        'Local Government', 'N.A.', 'National/Sovereign Government',
#        'Other Subsidiary of Parent', 'Parent', 'Parent & Subsidiaries',
#        'Subsidiaries'], dtype=object), array(['BONDS', 'COMPANY GUARNT', 'COVERED', 'GOVT GUARANTEED',
#        'GOVT LIQUID GTD', 'INSURED', 'JR SUBORDINATED',
#        'JUMBO PFANDBRIEF', 'LOCAL GOVT GUARN', 'PFANDBRIEFE', 'SECURED',
#        'SR SECURED', 'SR SUBORDINATED', 'SR UNSECURED', 'SUBORDINATED',
#        'UNSECURED'], dtype=object), array([False, True], dtype=object), array([False, True], dtype=object)]
# moyenne = 9.530062814171843e-18
# moyenne = -0.00042470152026945657

# %% [markdown]
# # 2. Modéles de prédiction des probabilités de défaut

# %% [markdown]
# Nous considérons les modèles de prédiction suivant :
#
# a. **Réseau de neurones** : Deep Learning, apprentissage par une compilation de couches entre les variables d'entrée et l'output.
#
# b. **k-NN** : on définit une métrique entre les observations. Pour chaque observation, on définit ses $k$ plus proches voisins et on fait la moyenne de leur probabilité de défaut pour estimer la probabilité de défaut de l'observation initiale.
#
# c. **SVM-R** : machines à vecteurs de support en régression.
#
# *cf la documentation pour l'explication détaillée de ces algorithmes de Machine Learning*

# %% [markdown]
# ## a. Réseau de neurones

# %% [markdown]
# ## Entraînement du modèle

# %%
model = Sequential()
model.add(Dense(units=1200,input_dim=68,))#activation="sigmoid")) #6 is good
model.add(Dense(units=1200))
model.add(Dense(units=1200))
#model.add(Dropout(0.2))
model.add(Dense(units=1,activation="sigmoid"))

learning_rate = 0.000005

sgd = SGD(learning_rate)  #lr = 0.02
adam = Adam(learning_rate) #lr = 0.001

#nadam = Nadam(lr=0.0005, beta_1=0.9, beta_2=0.999)

# %%
model.compile(loss='mean_absolute_percentage_error',optimizer=adam,metrics=[tf.keras.metrics.MeanAbsolutePercentageError()])

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 1200)              82800
# _________________________________________________________________
# dense_5 (Dense)              (None, 1200)              1441200
# _________________________________________________________________
# dense_6 (Dense)              (None, 1200)              1441200
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 1201
# =================================================================
# Total params: 2,966,401
# Trainable params: 2,966,401
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callback = keras.callbacks.EarlyStopping(monitor='loss', patience=3)
#callback = None
history = model.fit(np.squeeze(X_train), y_train,         # Train the model using the training set...
          batch_size=30, epochs=30,
          verbose=1, validation_split=0.2,steps_per_epoch=120,)#callbacks=[callback])           # ...holding out 40% of the data for validation

# --------------------------------------
# Evaluation
# --------------------------------------
for loss_name, loss_value in list(zip(model.metrics_names, model.evaluate(X_test, y_test, verbose=1))):
    print('The final {} on the TEST set is: {:.2f}.'.format(loss_name, loss_value)) # Evaluate the trained model on the test set!

    
import matplotlib.pyplot as plt

# --------------------------------------
# Loss functions evolution
# --------------------------------------
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='right')
#plt.savefig('nn.png')
plt.show()
# Out:
# Epoch 1/30
# 120/120 [==============================] - 5s 40ms/step - loss: 7340.4912 - mean_absolute_percentage_error: 7340.4912 - val_loss: 2716.6431 - val_mean_absolute_percentage_error: 2716.6431
# Epoch 2/30
# 120/120 [==============================] - 5s 39ms/step - loss: 1680.1127 - mean_absolute_percentage_error: 1680.1127 - val_loss: 1175.2277 - val_mean_absolute_percentage_error: 1175.2278
# Epoch 3/30
# 120/120 [==============================] - 5s 41ms/step - loss: 1555.7100 - mean_absolute_percentage_error: 1555.7100 - val_loss: 454.8592 - val_mean_absolute_percentage_error: 454.8592
# Epoch 4/30
# 120/120 [==============================] - 5s 40ms/step - loss: 439.3262 - mean_absolute_percentage_error: 439.3262 - val_loss: 310.1262 - val_mean_absolute_percentage_error: 310.1262
# Epoch 5/30
# 120/120 [==============================] - 5s 41ms/step - loss: 329.3359 - mean_absolute_percentage_error: 329.3359 - val_loss: 228.8564 - val_mean_absolute_percentage_error: 228.8564
# Epoch 6/30
# 120/120 [==============================] - 5s 41ms/step - loss: 249.6792 - mean_absolute_percentage_error: 249.6792 - val_loss: 181.6857 - val_mean_absolute_percentage_error: 181.6857
# Epoch 7/30
# 120/120 [==============================] - 5s 40ms/step - loss: 192.8670 - mean_absolute_percentage_error: 192.8670 - val_loss: 154.3890 - val_mean_absolute_percentage_error: 154.3890
# Epoch 8/30
# 120/120 [==============================] - 5s 38ms/step - loss: 162.5810 - mean_absolute_percentage_error: 162.5810 - val_loss: 134.6834 - val_mean_absolute_percentage_error: 134.6834
# Epoch 9/30
# 120/120 [==============================] - 5s 38ms/step - loss: 156.5666 - mean_absolute_percentage_error: 156.5666 - val_loss: 119.5852 - val_mean_absolute_percentage_error: 119.5852
# Epoch 10/30
# 120/120 [==============================] - 5s 39ms/step - loss: 214.6843 - mean_absolute_percentage_error: 214.6843 - val_loss: 105.3439 - val_mean_absolute_percentage_error: 105.3439
# Epoch 11/30
# 120/120 [==============================] - 5s 40ms/step - loss: 109.7575 - mean_absolute_percentage_error: 109.7575 - val_loss: 100.3540 - val_mean_absolute_percentage_error: 100.3540
# Epoch 12/30
# 120/120 [==============================] - 5s 39ms/step - loss: 96.7672 - mean_absolute_percentage_error: 96.7672 - val_loss: 96.9469 - val_mean_absolute_percentage_error: 96.9469
# Epoch 13/30
# 120/120 [==============================] - 5s 38ms/step - loss: 101.1377 - mean_absolute_percentage_error: 101.1377 - val_loss: 93.8498 - val_mean_absolute_percentage_error: 93.8498
# Epoch 14/30
# 120/120 [==============================] - 5s 40ms/step - loss: 116.5988 - mean_absolute_percentage_error: 116.5988 - val_loss: 89.9563 - val_mean_absolute_percentage_error: 89.9563
# Epoch 15/30
# 120/120 [==============================] - 5s 40ms/step - loss: 92.9520 - mean_absolute_percentage_error: 92.9520 - val_loss: 88.3897 - val_mean_absolute_percentage_error: 88.3897
# Epoch 16/30
# 120/120 [==============================] - 5s 38ms/step - loss: 103.0266 - mean_absolute_percentage_error: 103.0266 - val_loss: 86.5207 - val_mean_absolute_percentage_error: 86.5207
# Epoch 17/30
# 120/120 [==============================] - 5s 39ms/step - loss: 97.7910 - mean_absolute_percentage_error: 97.7910 - val_loss: 85.2570 - val_mean_absolute_percentage_error: 85.2570
# Epoch 18/30
# 120/120 [==============================] - 5s 39ms/step - loss: 128.9178 - mean_absolute_percentage_error: 128.9178 - val_loss: 84.8050 - val_mean_absolute_percentage_error: 84.8050
# Epoch 19/30
# 120/120 [==============================] - 5s 39ms/step - loss: 86.6866 - mean_absolute_percentage_error: 86.6866 - val_loss: 84.5145 - val_mean_absolute_percentage_error: 84.5145
# Epoch 20/30
# 120/120 [==============================] - 5s 38ms/step - loss: 86.5925 - mean_absolute_percentage_error: 86.5925 - val_loss: 83.8825 - val_mean_absolute_percentage_error: 83.8825
# Epoch 21/30
# 120/120 [==============================] - 5s 41ms/step - loss: 80.6518 - mean_absolute_percentage_error: 80.6518 - val_loss: 83.5397 - val_mean_absolute_percentage_error: 83.5397
# Epoch 22/30
# 120/120 [==============================] - 5s 39ms/step - loss: 84.0175 - mean_absolute_percentage_error: 84.0175 - val_loss: 83.1688 - val_mean_absolute_percentage_error: 83.1688
# Epoch 23/30
# 120/120 [==============================] - 5s 38ms/step - loss: 85.2785 - mean_absolute_percentage_error: 85.2785 - val_loss: 82.9029 - val_mean_absolute_percentage_error: 82.9029
# Epoch 24/30
# 120/120 [==============================] - 5s 40ms/step - loss: 85.2695 - mean_absolute_percentage_error: 85.2695 - val_loss: 82.4386 - val_mean_absolute_percentage_error: 82.4386
# Epoch 25/30
# 120/120 [==============================] - 5s 40ms/step - loss: 89.9681 - mean_absolute_percentage_error: 89.9681 - val_loss: 82.1106 - val_mean_absolute_percentage_error: 82.1106
# Epoch 26/30
# 120/120 [==============================] - 5s 38ms/step - loss: 104.3725 - mean_absolute_percentage_error: 104.3725 - val_loss: 82.8634 - val_mean_absolute_percentage_error: 82.8634
# Epoch 27/30
# 120/120 [==============================] - 5s 39ms/step - loss: 85.1665 - mean_absolute_percentage_error: 85.1665 - val_loss: 82.4118 - val_mean_absolute_percentage_error: 82.4118
# Epoch 28/30
# 120/120 [==============================] - 5s 40ms/step - loss: 90.3972 - mean_absolute_percentage_error: 90.3972 - val_loss: 82.2707 - val_mean_absolute_percentage_error: 82.2707
# Epoch 29/30
# 120/120 [==============================] - 5s 38ms/step - loss: 85.8045 - mean_absolute_percentage_error: 85.8045 - val_loss: 82.2639 - val_mean_absolute_percentage_error: 82.2639
# Epoch 30/30
# 120/120 [==============================] - 5s 39ms/step - loss: 82.7992 - mean_absolute_percentage_error: 82.7992 - val_loss: 81.9706 - val_mean_absolute_percentage_error: 81.9706
# 113/113 [==============================] - 1s 7ms/step - loss: 218.9731 - mean_absolute_percentage_error: 218.9731
# The final loss on the TEST set is: 218.97.
# The final mean_absolute_percentage_error on the TEST set is: 218.97.

# %% [markdown]
# ## Observation des résultats

# %% [markdown]
# *Fonctions pour afficher les résultats*

# %%
def ecart_relatif(row) : 
    théo = row['Théorique']
    préd = row['Prédiction']
    return np.abs(théo - préd) / théo

# %%
def ViewResults(model, X_test, y_test):
    prediction = pd.DataFrame(data= model.predict(X_test) ,columns=['Prédiction'])
    théorique = pd.DataFrame(data= y_test ,columns=['Théorique'])
    prediction, théorique = prediction.reset_index() , théorique.reset_index()

    results = pd.merge(théorique, prediction, on = 'index').drop(columns=['index'])
    results["Ecart_relatif"] = results.apply(ecart_relatif,axis=1)
    
    results.sort_values('Ecart_relatif',inplace=True)
    
    #print(results.tail(20))
    k=.2
    
    
    print("\n\nL'écart relatif moyen est de " + str(results["Ecart_relatif"].mean() * 100) + "%")
    premiere_bissectrice = np.linspace(0,k * 1e-1,100)
    
    plt.plot(premiere_bissectrice,premiere_bissectrice, color='red')
    plt.scatter(results["Théorique"],results["Prédiction"], s = 1)
    
    
    plt.xlim(-k*1e-2,k * 1e-1)
    plt.ylim(-k*1e-2,k * 1e-1)
    plt.savefig('svr_pred.png')
    plt.show()

# %% [markdown]
# *Résultats du réseau de neurones*

# %%
#Résultats 

resultat = model.evaluate(X_test, y_test, verbose=1)
print("Valeur de l'erreur sur les données de test (loss):", resultat[0])
print('Précision sur les données de test (MAPE):', resultat[1])
# Out:
# 113/113 [==============================] - 1s 7ms/step - loss: 218.9731 - mean_absolute_percentage_error: 218.9731
# Valeur de l'erreur sur les données de test (loss): 218.97311401367188
# Précision sur les données de test (MAPE): 218.97311401367188

# %%
print('Resultat pour la regression via Dense Neural Net')
ViewResults(model,X_test,y_test)
# Out:
# Resultat pour la regression via Dense Neural Net
#
#
# L'écart relatif moyen est de 218.9731131817543%

# %%
ViewResults(model,X_train,y_train)
# Out:
# L'écart relatif moyen est de 85.42126628514933%

# %% [markdown]
# ## b. K-NN

# %% [markdown]
# *Choix de la valeur de K*

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
scores, k_ = [], []
for k in range(1,20) : 
    neigh = KNeighborsRegressor(n_neighbors=k)
    neigh.fit(X_train, y_train)
    scores.append(neigh.score(X_test, y_test))
    k_.append(k)
    
plt.plot(k_,scores)
plt.xlabel('Nombre k de voisins')
plt.ylabel('Score')
print("Score maximum pour k = " + str(k_[scores.index(max(scores))]) )
# Out:
# Score maximum pour k = 3

# %% [markdown]
# *Modèle*

# %%
neigh = KNeighborsRegressor(n_neighbors=3)
neigh.fit(X_train, y_train)
neigh.score(X_test, y_test)
# Out:
# 0.5312897255922633

# %%
print('Resultat pour la regression 3-NN')
ViewResults(neigh,X_test,y_test)
# Out:
# Resultat pour la regression 3-NN
#
#
# L'écart relatif moyen est de 158.51955314660097%

# %%
ViewResults(neigh,X_train,y_train)
# Out:
# L'écart relatif moyen est de 70.07239157256429%

# %% [markdown]
# ## c. SVR

# %% [markdown]
# *Valeur de la régression à justifier*

# %%
from sklearn.svm import SVR
regr = SVR(C=1.3789473684210527, epsilon=0.0000514545454545455, verbose=False)
regr.fit(X_train, y_train)
regr.score(X_test, y_test)
# Out:
# 0.40535691630105575

# %%
print('Resultat pour la regression SVR')
ViewResults(regr, X_test, y_test)
# Out:
# Resultat pour la regression SVR
#
#
# L'écart relatif moyen est de 212.69862747955256%
